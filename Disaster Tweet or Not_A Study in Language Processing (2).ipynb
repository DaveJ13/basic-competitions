# %%
import numpy as np
import pandas as pd
import seaborn as sns
import re
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import classification_report
import nltk
from nltk.corpus import stopwords
#nltk.download('stopwords')
from sklearn.model_selection import train_test_split
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import RidgeClassifier

# %%
pd.options.display.max_colwidth = 200
dftest1 = pd.read_csv("test1.csv")
dftrain1 = pd.read_csv("train1.csv")

# %%
dftest1["text"].shape
# Out:
# (3263,)

# %%
dftrain1["text"].shape
# Out:
# (7613,)

# %%
dftrain1
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                                                                                                            text  \
# 0                                                                         Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all
# 1                                                                                                        Forest fire near La Ronge Sask. Canada
# 2         All residents asked to 'shelter in place' are being notified by officers. No other evacuation or shelter in place orders are expected
# 3                                                                             13,000 people receive #wildfires evacuation orders in California
# 4                                                      Just got sent this photo from Ruby #Alaska as smoke from #wildfires pours into a school
# ...                                                                                                                                         ...
# 7608                                                        Two giant cranes holding a bridge collapse into nearby homes http://t.co/STfMbbZFB5
# 7609              @aria_ahrary @TheTawniest The out of control wild fires in California even in the Northern part of the state. Very troubling.
# 7610                                                                          M1.94 [01:04 UTC]?5km S of Volcano Hawaii. http://t.co/zDtoyd8EbJ
# 7611  Police investigating after an e-bike collided with a car in Little Portugal. E-bike rider suffered serious non-life threatening injuries.
# 7612                                             The Latest: More Homes Razed by Northern California Wildfire - ABC News http://t.co/YmY4rSkQ3d
#
#       target
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 7608       1
# 7609       1
# 7610       1
# 7611       1
# 7612       1
#
# [7613 rows x 5 columns]

# %%
print(dftest1.isnull().sum())
print(dftrain1.isnull().sum())
# Out:
# id             0
# keyword       26
# location    1105
# text           0
# dtype: int64
# id             0
# keyword       61
# location    2533
# text           0
# target         0
# dtype: int64

# %%
dftrain1.isnull().sum()
# Out:
# id             0
# keyword       61
# location    2533
# text           0
# target         0
# dtype: int64

# %%
print(dftest1.info())
print(dftrain1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3263 entries, 0 to 3262
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        3263 non-null   int64
#  1   keyword   3237 non-null   object
#  2   location  2158 non-null   object
#  3   text      3263 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 102.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7613 entries, 0 to 7612
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        7613 non-null   int64
#  1   keyword   7552 non-null   object
#  2   location  5080 non-null   object
#  3   text      7613 non-null   object
#  4   target    7613 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 297.5+ KB
# None

# %%
print(dftest1.keys())
print(dftrain1.keys())
# Out:
# Index(['id', 'keyword', 'location', 'text'], dtype='object')
# Index(['id', 'keyword', 'location', 'text', 'target'], dtype='object')

# %% [markdown]
# ### Run the models with the PorterStemmer and CountVectorizer
# #### I know I can iterate over these, but I prefer it this way.
# #### I am running a MultinomialNB, GaussianNB, Decision Tree, Logistic Regression, Random Forest, KNN, and a Ridge Classifier.

# %%
# Clean the tweets
stemmer = PorterStemmer()
stop_words = stopwords.words("english")
def clean_tweet(X5):
    if type(X5) == np.float:
        return ""
    tweet = X5.lower()
    tweet = re.sub("'", "", tweet) 
    tweet = re.sub("@[A-Za-z0-9_]+","", tweet)
    tweet = re.sub("#[A-Za-z0-9_]+","", tweet)
    tweet = re.sub(r'http\S+', '', tweet)
    tweet = re.sub('[()!?]', ' ', tweet)
    tweet = re.sub('\[.*?\]',' ', tweet)
    tweet = re.sub("[^a-z0-9]"," ", tweet)
    tweet = tweet.split()
    tweet =[stemmer.stem(word) for word in tweet if (word not in stop_words)]
    tweet = " ".join(word for word in tweet)
    
    return tweet

# %%
X5 = dftrain1["text"]
trainclean = [clean_tweet(tw) for tw in X5]
trainclean
# Out:
# ['deed reason may allah forgiv us',
#  'forest fire near la rong sask canada',
#  'resid ask shelter place notifi offic evacu shelter place order expect',
#  '13 000 peopl receiv evacu order california',
#  'got sent photo rubi smoke pour school',
#  'updat california hwi 20 close direct due lake counti fire',
#  'heavi rain caus flash flood street manit colorado spring area',
#  'im top hill see fire wood',
#  'there emerg evacu happen build across street',
#  'im afraid tornado come area',
#  'three peopl die heat wave far',
#  'haha south tampa get flood hah wait second live south tampa gonna gonna fvck',
#  '18 19 day ive lost count',
#  'bago myanmar arriv bago',
#  'damag school bu 80 multi car crash',
#  'what man',
#  'love fruit',
#  'summer love',
#  'car fast',
#  'goooooooaaaaaal',
#  'ridicul',
#  'london cool',
#  'love ski',
#  'wonder day',
#  'looooool',
#  'way cant eat shit',
#  'nyc last week',
#  'love girlfriend',
#  'cooool',
#  'like pasta',
#  'end',
#  'wholesal market ablaz',
#  'alway tri bring heavi',
#  'break news nigeria flag set ablaz aba',
#  'cri set ablaz',
#  'plu side look sky last night ablaz',
#  'theyv built much hype around new acquisit doubt set epl ablaz season',
#  'inec offic abia set ablaz',
#  'barbado jamaica two car set ablaz santa cruz head st elizabeth polic superintend',
#  'ablaz lord',
#  'check',
#  'outsid your ablaz aliv your dead insid',
#  'awesom time visit cfc head offic ancop site ablaz thank tita vida take care us',
#  'soooo pump ablaz',
#  'want set chicago ablaz preach hotel',
#  'gain 3 follow last week know stat grow',
#  'west burn thousand wildfir ablaz california alon',
#  'build perfect tracklist life leav street ablaz',
#  'check',
#  'first night retain quit weird better get use wear everi singl night next year least',
#  'deputi man shot brighton home set ablaz',
#  'man wife get six year jail set ablaz niec',
#  'santa cruz head st elizabeth polic superintend lanford salmon r',
#  'polic arsonist deliber set black church north carolina ablaz',
#  'noch el bestia happi see teammat train hard goodnight gunner',
#  'trampl turkmen flag later set ablaz other vandal offic turkmen front',
#  'truck ablaz r21 voortrekk ave outsid tambo intl cargo section',
#  'set heart ablaz everi citi gift everi skylin like kiss upon lip',
#  'sky ablaz tonight lo angel im expect ig fb fill sunset shot know peep',
#  'west burn thousand wildfir ablaz alon',
#  'revel wmv video mean mac farewel ablaz wmv en rout dvd gtxrwm',
#  'progress greet month student would set pen ablaz torch public',
#  'rene ablaz amp jacinta secret 2k13 fallen sky edit mar 30 2013',
#  'steve fire someth els california tinderbox clown set hood ablaz',
#  'rene ablaz amp ian buff magnitud',
#  'huge fire wholesal market ablaz',
#  'time talk go dont know make due work',
#  'cant kid cuz got bicycl accid amp split testicl imposs kid michael father',
#  'accid 24 w traffic move 8m slower usual',
#  'accid center lane block us 101 nb great america pkwi',
#  'accid summer read advic amp see help',
#  'speed among top caus teen accid car accid tee',
#  'report motor vehicl accid curri herman rd near stephenson involv overturn vehicl pleas use',
#  'bigrigradio live accid awar',
#  '77 mile marker 31 south mooresvil iredel vehicl accid ramp close 8 6 1 18 pm',
#  'rt sleep pill doubl risk car accid',
#  'accid knew gon happen',
#  'traffic accid n cabrillo hwi magellan av mir 08 06 15 11 03 58',
#  '77 mile marker 31 40 south mooresvil iredel vehicl accid congest 8 6 1 18 pm',
#  'pastor scene accid owner rang rover',
#  'mom didnt get home fast wish mom accid truck spilt mayonnais',
#  'horribl car accid past sunday im final abl get around thank god',
#  'wait see piss donni tell anoth accid',
#  'overturn interst click youv crash gt',
#  'accid us 23 sb sr 752',
#  'carolina accid motorcyclist die 540 crash car cross median motorcycl rider travel',
#  'fyi cad fyi accid properti damag nh 999 piner rd horndal dr',
#  'rt naayf first accid year turn onto chandane magu near mma taxi ram halfway turn everyon conf',
#  'accid left lane block rt 293 nb eddi rd stop go traffic back nh 3a delay 4 min',
#  'accid properti damag piner rd horndal dr',
#  'accid',
#  'fyi cad fyi accid properti damag wpd 1600 17th st',
#  '8 6 2015 09 pm traffic accid injuri 2781 willi foreman rd',
#  'aashiqui actress anu aggarw near fatal accid',
#  'suffield alberta accid',
#  '9 mile backup 77 south accid block right 2 lane exit 31 langtre rd consid nc 115 nc 150 nc 16 altern',
#  'accid chang life help determin option financi support life care plan go treatment',
#  'deadli motorcycl car accid happen today ill detail 5',
#  'marinad accid',
#  'car even week got fuck car accid mf cant fuck drive',
#  'polic previous die road accid kill explos',
#  'still heard church leader kenya come forward comment accid issu disciplinari measur',
#  'scuf ps live game cya',
#  'man drive effort get pain man win roger bannist',
#  '320 icemoon',
#  'victori bargain basement price dwight david eisenhow',
#  '320 icemoon',
#  'nobodi rememb came second charl schulz',
#  'im speak someon use scuf xb1 peopl end get ps also',
#  'harder conflict gloriou triumph thoma pain',
#  'go clay pigeon shoot cri aftershock',
#  'guess one actual want free aftershock tc',
#  'aftershock terrifi best roller coaster ive ever disclaim ive',
#  'aftershock',
#  '320 icemoon',
#  '320 icemoon',
#  '320 icemoon',
#  'im see issu aftershock',
#  '320 icemoon',
#  '320 icemoon',
#  'bonu 5 minut daili habit could realli improv life mani alreadi',
#  'aftershock protect profit next global financi meltdown david wiedem http',
#  'moment get scari roller coaster guy behind scream bloodi murder',
#  'aftershock 2010 full stream youtub',
#  'gt gt 15 aftershock protect profit next global financi',
#  'sometim face difficulti your someth wrong your someth right joel osteen',
#  'thing stand dream tri belief actual possibl joel brown',
#  'prais god ministri tell like',
#  'rememb go die best way know avoid trap think someth lose steve job',
#  'tri orang aftershock today life never',
#  'love bb',
#  'aftershock',
#  'aftershock back school kick great want thank everyon make possibl great night',
#  'peopl say cannot done interrupt georg bernard shaw',
#  'first man get oyster second man get shell andrew carnegi',
#  'anyon need p u tonight play hybrid slayer ps4 eu hmu',
#  'expert franc begin examin airplan debri found reunion island french air accid expert',
#  'strict liabil context airplan accid pilot error common compon aviat cr',
#  'lifetim odd die airplan accid 1 8015',
#  'expert franc begin examin airplan debri found reunion island french air accid expert wedn',
#  'awwww theyr airplan accid theyr gonna die cuti good job',
#  'famili member osama bin laden die airplan accid iron mhmmm gov shit suspect',
#  'man goe airplan engin accid via',
#  'horribl accid man die wing airplan 29 07 2015',
#  'cessna airplan accid ocampo coahuila mexico juli 29 2015 kill four men includ state coahuila govern offici',
#  'man die wing airplan 29 07 2015',
#  'expert franc begin examin airplan debri found reunion island french air accid expert wednesday',
#  'expert franc begin examin airplan debri found reunion island french air accid expert wednesday began examin',
#  'mbataweel famili member kill airplan accid',
#  'almost sent cowork nude accid thank god airplan mode',
#  'might kill airplan accid night car wreck polit best',
#  'expert franc begin examin airplan debri found reunion island french air accid expert',
#  'unbeliev insan',
#  'horribl accid man die wing airplan 29 07 2015',
#  'horribl accid man die wing airplan 29 07 2015',
#  'usama bin ladin famili dead airplan crash natur accid',
#  'pilot die plane crash car festiv via',
#  'strict liabil context airplan accid',
#  'dtn brazil expert franc begin examin airplan debri found reunion island french air accid exp',
#  'expert franc begin examin airplan debri found reunion island french air accid expert wedn',
#  'horribl accid man die wing airplan 29 07 2015 wtf believ eye',
#  'nicol fletcher one victim crash airplan time ago accid left littl bit trauma although she',
#  'omg horribl accid man die wing airplan',
#  'dont believ bro',
#  'expert franc begin examin airplan debri found reunion island french air accid expert wednesday began examin',
#  'airplan accid',
#  'phone look like car ship airplan accid terribl',
#  'statist im risk get kill cop die airplan accid',
#  'airplan crash hous colombia 12 peopl die accid',
#  'shoot airplan accid',
#  'could drone caus airplan accid pilot worri use drone esp close vicin airport',
#  'earli wake call sister beg come amp ride w ambul hospit',
#  'twelv fear kill pakistani air ambul helicopt crash',
#  'two air ambul scene seriou crash two car lorri',
#  'twelv fear kill pakistani air ambul helicopt crash reuter',
#  'lead emerg servic boss welcom new ambul chariti',
#  'anyon travel aberystwyth shrewsburi right there incid servic halt outsid shrew ambul scene',
#  'twelv fear kill pakistani air ambul helicopt crash',
#  'ambul sprinter automat frontlin vehicl choic 14 lez compliant ebay',
#  'new nanotech devic abl target destroy blood clot',
#  'hella crazi 3 fight ambul coupl mosh pit',
#  'get run ambul lucki',
#  'twelv fear kill pakistani air ambul helicopt crash',
#  'twelv fear kill pakistani air ambul helicopt crash',
#  'wait ambul',
#  'ok need ambul hahahah good',
#  'ambul sprinter automat frontlin vehicl choic 14 lez compliant ebay',
#  'pakistan air ambul helicopt crash kill nine',
#  'nissan ok need medic assist call ambul need',
#  'ems1 ny emt petit 17 per hour minimum wage',
#  'twelv fear kill pakistani air ambul helicopt crash',
#  'twelv fear kill pakistani air ambul helicopt crash',
#  'ambul sprinter automat frontlin vehicl choic 14 lez compliant ebay',
#  'ambul sprinter automat frontlin vehicl choic 14 lez compliant ebay',
#  'check what park lot said last year ambul st john',
#  'dont know way ambul come lt lt',
#  'twelv fear kill pakistani air ambul helicopt crash',
#  'twelv fear kill pakistani air ambul helicopt crash',
#  'ambul right outsid work',
#  'dog think he ambul',
#  'happen hatzolah em ambul respond dual siren',
#  'twelv fear kill pakistani air ambul helicopt crash',
#  'twelv fear kill pakistani air ambul helicopt crash',
#  'twelv fear kill pakistani air ambul helicopt crash',
#  'twelv fear kill pakistani air ambul helicopt crash',
#  'what polic ambul number lesotho bodi know',
#  'surpris still cannot standardis clinic practic across 11 nh ambul trust',
#  'twelv fear kill pakistani air ambul helicopt crash',
#  'peopl tri j walk ambul pass hate',
#  'episod trunk annihil freiza cleanest shit ever show nigga merci',
#  'shall annihil petebest dessic laid bare shall kneel',
#  'urib annihil basebal',
#  'hey sundown annihil previou meet celtic inde improv',
#  'mizzou annihil florida past 2 season even end muschamp career cant compet bama',
#  'annihil ab',
#  'annihil statu educ mba behalf easi street careen eovm',
#  'luka die everyth annihil aloi tranci',
#  'good un fella sorri wont get annihil',
#  'cop pull drunk driver safeti second car hit train via',
#  'must annihil',
#  'cop pull drunk driver safeti second car hit train via',
#  'boom countri entir annihil h britain',
#  'would annihil might well thank',
#  'one thing sure god promis israel annihil horror iran w nuke',
#  'guess that ok armenian sinc weve spent histori get annihil',
#  '70 year sinc annihil 100000 peopl instantli becam awar abil annihil whole human',
#  'day 1 tryout went good minu fact stop quickli get short ball annihil toenail injuri even',
#  '1960 oryx symbol arabian peninsula annihil hunter',
#  'luka die everyth annihil aloi tranci',
#  'readi get annihil buc game',
#  'peopl annihil last night weather realli philip thought would forecast',
#  'domain sophist annihil close minut feat zrnf',
#  'seen juda priest 2005 rob came back scorpion support fuck annihil place astonish gig',
#  'offici skip whatev hashtag get annihil review bummer',
#  'thu explain annihil case survivor evolv becam godlik',
#  'complet annihil cech paul keegan time aliv',
#  'annihil legion survivor imperfect hybrid project quickli form new secret cell',
#  'exactli that lesnar cena match summerslam last year great brock annihil guy who',
#  'cop pull drunk driver safeti second car hit train via',
#  'annihil damascu syrian armi grind alloosh gang manur pile',
#  'ok wasnt complet forthright may also food coma bc kebab tahini pickl also annihil w fri',
#  'fun fill happi hour simmon bar camden handsom one got annihil apart game',
#  'juanni beisbol sr annihil ball',
#  'hell fraction belief total annihil destruct usa',
#  'mayb call israel tell sorri pre sold river annihil',
#  'evildead annihil civil',
#  'u nation park servic tonto nation forest stop annihil salt river wild hors via',
#  'annihil quarterstaff annihil',
#  'world annihil vs self transform alien attack extermin human',
#  'starmad stardat 3 planetari annihil via',
#  'u nation park servic tonto nation forest stop annihil salt river wild hors via',
#  'u nation park servic tonto nation forest stop annihil salt river wild hors via',
#  'pleas sign share petit save wild hors arizona',
#  'u nation park servic tonto nation forest stop annihil salt river wild hors via',
#  'pleas check salt river hors help stop annihil happen without 54000 signatur chang org thx',
#  'soul punish annihil',
#  'mention major contributor annihil israel',
#  'need help hors die pleas rt amp sign petit take stand amp voic',
#  'reject law misguid fals prophet imprison nation fuel self annihil',
#  'u nation park servic tonto nation forest stop annihil salt river wild hors via',
#  'annihil jeb christi amp kasich less 24 hour away pleas god allow least one full day',
#  'need help hors die pleas rt amp sign petit take stand amp voic',
#  'need help hors die pleas rt amp sign petit take stand amp voic',
#  'hey sign petit save sing long order',
#  'stop annihil salt river wild hors via',
#  'he current nova bookslast check tie book 2011 rider die annihil',
#  'u nation park servic tonto nation forest stop annihil salt river wild hors via',
#  'pleas sign amp rt save',
#  'thank dant join us follow zone johnni',
#  'world annihil vs self transform alien attack extermin human',
#  'u nation park servic tonto nation forest stop annihil salt river wild hors via',
#  'u nation park servic tonto nation forest stop annihil salt river wild hors via',
#  'im gonna fight taylor soon get',
#  'ohh fukurodani didnt surviv apocalyps bokuto feel horribl poor boy ppor child',
#  'anoth jocelyn birthday apocalyps',
#  'rt janenelson097 rt stephenscifi adapt watch charli human apocalyps option film',
#  'apocalyps pleas',
#  'anoth hour august 05 2015 08 02pm here red rover zombi apocalyps 2014',
#  'feel like pull one stage apocalyps',
#  'she kinda hot play radio today what next diseas apocalyps start everyon care',
#  'apocalyps lol gf m8',
#  'know question interpret sign apocalyps call',
#  'juli r apocalyps version romeo juliet',
#  'apocalyps upon us',
#  'rt fittscott minecraft night lucki block mod bob apocalyps wither 2 0 amp mod showcas popularmmo vi',
#  'begin day one snow apocalyps',
#  'rt mother mari short read apocalyps 21 1023 spirit angel took top enorm high mountain',
#  'candylit imagin sarumi zombi apocalyps fight back back heart heart convers',
#  'rt zonewolf123 like youtub video minecraft night lucki block mod bob apocalyps wither 2 0 amp mo',
#  'that planet lone audienc apocalyps',
#  'dad bought dvd look like scienc doc front read back actual impend biblic apocalyps',
#  'inde apocalyps come week know ill',
#  'go look grizzli peak right look like begin dystopian apocalyps movi',
#  'niec ask would scare apocalyps',
#  'there storm cairo latest x men apocalyps set photo via',
#  'minecraft night lucki block mod bob apocalyps wither 2 0 amp mod showcas popularmmo via',
#  'shot heart xv go total give love bad name heart pierc',
#  'rt geek apocalyps 4pm gmt hess play dark soul 2 day 9',
#  'know go zombi take',
#  'latest reveal queen',
#  'shadow box apocalyps',
#  'short read apocalyps 21 1023 spirit angel took top enorm high mountain',
#  'enjoy live action attack titan everi time see poster im remind freshli clean coif everyon apocalyps',
#  'like video minecraft night lucki block mod bob apocalyps wither 2 0 amp mod showcas',
#  'temporari 300 avysss kill flag fast xp reason',
#  'temporari 300 russaky89 kill flag fast xp reason',
#  'offici vid gt gt gt gt prod gt gt',
#  'ouvindo peac love amp armageddon',
#  'best movi youv ever seen armageddon',
#  'bed time dont wake unless revolut armageddon start',
#  'red faction armageddon microsoft xbox 360 2011 full read ebay',
#  'alreadi know shit goe world seri armageddon',
#  'rt lith 9 11',
#  'im gonna beat armageddon hsu hao got flawless first tri',
#  'ben affleck know there wife kid girl cant help ive love sinc armageddon',
#  'id long coat hand id worn certainti armageddon bear sens occas',
#  'phone spi hidden back door nsa data mine softwar financi armageddon blog',
#  'temporari 300 hyider ghost2 kill flag fast xp reason',
#  'rt lith 9 11',
#  'temporari 300 fighterdena kill flag fast xp reason',
#  'photo sketch base tast armageddon episod',
#  'armageddon',
#  'good luck tomorrow night get coeffici point plz',
#  'armageddon',
#  'your anoth one histori book thank justic depart way havent paid incom tax 20yr',
#  'vladimir putin issu major warn late escap armageddon',
#  'god kingdom heavenli govt rule peopl earth armageddon',
#  'l b lot 8 movi die hard 1 2 12 monkey armageddon sixth',
#  'let talk goof guild saunder come right stage',
#  'niec gain abil stand im get prepar toddler apocalyps armageddon',
#  'check must librari collect cd via',
#  'eep thought yesterday saw hella scari hail',
#  'ahamedi think messiah alreadi come 125 year ago armageddon dajaal gog amp magog',
#  'sadli window 10 reveal microsoft ethic armageddon',
#  'armageddon avert el patron',
#  'time 23 hour latest seri ww1 blueprint armageddon extrem impress',
#  'european fitba till christma armageddon',
#  'unit jew convert soon die armageddon',
#  'offici vid gt gt gt gt gt prod gt gt',
#  'tomorrow day start armageddon',
#  'lee comedi work class tori prepar armageddon',
#  '9 chart prove financi crisi part 2 begun financi armageddon econom collaps blog track tren',
#  'paul craig robert vladimir putin issu major warn late escap',
#  'your stage right light isnt funni get goofbal staff pd',
#  'offici vid gt gt gt gt gt gt gt gt gt comin soon',
#  'well done celtic finger cross aberdeen tomorrow night armageddon eh',
#  'beyonc pick fan armi 77',
#  'one direct pick fan armi x1402',
#  '5 second summer pick fan armi',
#  '22 beyonc pick fan armi',
#  '17 beyonc pick fan armi',
#  'one direct pick fan armi x1411',
#  'see armi whitewalk first thing slightli intrigu got far',
#  'build kingdom lead armi victori start g friend code lzktjnox',
#  'salvat armi host ralli reconnect father children salvat armi host back school ralli',
#  'vote vs 5th round',
#  'build armi 100 dog leader lion dog fight like lion',
#  'show hero tv review',
#  'one direct pick fan armi x1392',
#  'infantri men lume dial armi analog quartz wrist watch sport blue nylon fabric full rea',
#  'one direct pick fan armi x1441',
#  'victorinox swiss armi date women rubber mop watch 241487',
#  'rt drayesha4 indian armi ki',
#  '5 second summer pick fan armi 1',
#  'beyonc pick fan armi 78',
#  'one direct pick fan armi x1386',
#  'da one britney spear lana del rey',
#  'one direct pick fan armi',
#  'stoni jackson america last hope lead armi felon thu armi reject armi satan',
#  'wwi wwii japanes armi navi militari japan leather watch war mido ww1 2 full read ebay',
#  'beyonc pick fan armi 72',
#  '7 beyonc pick fan armi',
#  'beyonc pick fan armi 66',
#  '6 beyonc pick fan armi',
#  'potu appoint brig gen richard g kaiser member mississippi river commiss learn mrc',
#  'violent countri get armi involv help control kill bring back peac poor peopl',
#  'wwi wwii japanes armi navi militari japan leather watch war mido ww1 2 full read ebay',
#  'wwi wwii japanes armi navi militari japan leather watch war mido ww1 2 full read ebay',
#  'one direct pick fan armi x1434',
#  'one direct pick fan armi',
#  'two jewish terrorist charg histor church arson ugli truth',
#  'spokan author say theyr struggl solv arson case like today hamilton',
#  'thousand attend ralli organ peac protest arson attack took life',
#  'add familia arson squad',
#  'anoth fake hate crime lesbian burn hous els new',
#  'lo angel time arson suspect link 30 fire caught northern',
#  'mourn notic stab arson victim stir polit grief israel',
#  'mourn notic stab arson victim stir polit grief israel',
#  'sound arson',
#  'owner chicago area gay bar admit arson scheme',
#  'wait',
#  'arson suspect link 30 fire caught northern california',
#  'trial date set man charg arson burglari',
#  'death palestinian toddler arson attack israel crack jewish',
#  'palestinian teen kill amid protest arson attack',
#  'polic kisii hunt student fail arson plot polic kisii hunt student',
#  'mariah get thick shoulder poor girl',
#  'mourn notic stab arson victim stir polit grief israel poster shira banki',
#  'relaxinpr miprv rt latim arson suspect link 30 fire caught northern california',
#  'jewish leader pray hospit palestinian famili treat arson via',
#  'owner chicago area gay bar admit arson scheme via',
#  'angel arson',
#  'polic kisii hunt student fail arson plot polic kisii hunt student',
#  'mourn notic stab arson victim stir polit grief israel',
#  'owner chicago area gay bar admit arson scheme via',
#  'owner chicago area gay bar admit arson scheme',
#  'mourn notic stab arson victim stir polit grief israel',
#  'owner chicago area gay bar admit arson scheme',
#  'arson suspect link 30 fire caught northern california via',
#  'tennesse lesbian coupl fake hate crime destroy home arson',
#  'arson suspect link 30 fire caught northern california lo angel time',
#  'arson suspect link 30 fire caught northern california',
#  'hate white peopl mo',
#  'arsonist mc impress',
#  'alleg east bay serial arsonist arrest',
#  'minor citat posses decrimin substanc im face time',
#  'suspect serial arsonist arrest calif',
#  'arson suspect link 30 fire caught northern california',
#  'legal system never forget',
#  'u dick',
#  'bloor ossington arsonist also burn mattress northumberland st',
#  'where arsonist',
#  'dont anyth nice say come sit',
#  'video show arsonist torch popular bk restaur strictli vegetarian',
#  'arrest set mani fire watch tonight',
#  'video captur man remov american flag long beach ca home burn arsonist sought',
#  'trick think nasti thing',
#  'take paradis arsonist mc',
#  'make',
#  'town salem melt ice cube bc im arsonist',
#  'arsonist blame blaze plastic recycl busi adelaid report',
#  'hotboy shit',
#  'zodiac girl feat trey dupre produc sparkz beatz chuck da arsonist',
#  'lmfao',
#  'alleg east bay serial arsonist arrest',
#  'im jokin still cant move',
#  'guess u say shit think',
#  'arsonist set nyc vegetarian restaur fire polic',
#  'like video town salem win arsonist',
#  'what crack cuz',
#  'smoke good fuck eat drink drive nice car wear green mink',
#  'kill got court day earl',
#  'lmao real live go',
#  'owner chicago area gay bar admit arson scheme frank elliott plead guilti hire arsonist',
#  'trust iran stop terror like invit arsonist join fire brigad telegraph',
#  'big top burn true stori arsonist miss girl',
#  'stay vigil civil liberti constant attack',
#  'credit inspir rediscov fantabul',
#  'nashvil theater attack gun grabber demand hatchet control',
#  'break terror attack polic post',
#  'demi stan realli think heart attack sold 5 6 million copi',
#  'scare there new version nuclear attack warn like know govern still prepar',
#  'isil claim suicid bomb saudi mosqu kill least 15',
#  'funniest part twitter feminist tri attack 4head',
#  'horrif attack wife muslim itali liveleak',
#  '93 blast accus yeda yakub die karachi heart attack',
#  'us drone attack kill 4 suspect milit north waziristan',
#  'suspect latest theater attack psycholog issu',
#  'milit attack polic post udhampur 2 spo injur livemint',
#  'break obama offici gave muslim terrorist weapon use texa attack',
#  'delhi govern provid free treatment acid attack victim privat hospit',
#  'new post new smb relay attack steal user credenti internet',
#  'isra forc raid home alleg car attack suspect',
#  'heart attack thought goat dead dont worri rocket okay',
#  'im gonna lie im kinda readi attack senior year',
#  'left hand side diamond graveyard shift attack defend right handsid fuck idiot',
#  'attack ii volleybal train machin set simul',
#  'notley tact yet direct respons harper attack alberta govt hell yeah premier',
#  'polic assail latest us movi theatr attack homeless psycholog issu',
#  'thank damn heart attack',
#  'suspect latest us theatr attack psycholog issu',
#  'india shud give evid 2 pak share terrorist amp use next attack share oth contri',
#  'illeg alien releas obama dh 4 time charg rape amp murder santa maria ca woman prior offens',
#  'strongli condemn attack ari news team karachi cowardli act simpli tri job',
#  'nashvil theater attack gun grabber demand hatchet control',
#  'fact atom bomb call littl boy fat man say lot mental went attack',
#  'everyon see ignorancesh latinoand ever benoth morebut attack dog 4 hate group gop',
#  'heart diseas prevent secondhand smoke',
#  'dayton area org tell hit cyber attack',
#  'attack titan game ps vita yay cant wait 2016',
#  'nashvil theater attack gun grabber demand hatchet control',
#  'anxieti attack',
#  'dog attack food',
#  'cop injur gunfight milit attack udhampur polic post suspect milit attack polic post',
#  'ask feel attack juli ask frail',
#  'feel attack',
#  'im feel attack',
#  'black men didnt make way white men black men get attack',
#  'cant believ fuck ci femal go somehow claim offend transgend femal who attack media',
#  'isra helicopt attack civilian gaza complet exercis greec',
#  'christian attack muslim templ mount wave isra flag via pamela geller',
#  'christian attack muslim templ mount wave isra flag via pamela geller',
#  'christian attack muslim templ mount wave isra flag via pamela geller',
#  'unit attack respons target muslim scholar imprison youth',
#  'telnet attack 124 13 172 40 streamyx home southern',
#  'christian attack muslim templ mount wave isra flag via pamela geller',
#  'rememb time patrick kane attack cab driver 20',
#  'im feel attack',
#  'ik troll pol rival never liter abus attack famili liter abus ik looser',
#  'christian attack muslim templ mount wave isra flag via pamela geller',
#  'christian attack muslim templ mount wave isra flag via pamela geller',
#  'worst person question juli attack guy empathi',
#  'kelli osbourn attack racist donald trump remark latino view',
#  'aiii need chill answer calmli like she attack',
#  'christian attack muslim templ mount wave isra flag via pamela geller',
#  'christian attack muslim templ mount wave isra flag via pamela geller',
#  'christian attack muslim templ mount wave isra flag via pamela geller',
#  'attack robot lvl 19 ive earn total 6615434 free satoshi',
#  'christian attack muslim templ mount wave isra flag via pamela geller',
#  'saw tweet feel realli attack',
#  'christian attack muslim templ mount wave isra flag via pamela geller',
#  'christian attack muslim templ mount wave isra flag via pamela geller',
#  'christian attack muslim templ mount wave isra flag via pamela geller',
#  'tv program saw said us air plane flew uranium mine fukushima attack machin gun student armi dig',
#  'christian attack muslim templ mount wave isra flag via pamela geller',
#  'lt thing get attack',
#  'christian attack muslim templ mount wave isra flag via pamela geller',
#  'avalanch defens match vs st loui blue',
#  'like video kall mattson avalanch offici video',
#  'well crash like avalanch',
#  'men offici colorado avalanch reebok shirt xl blue 100 cotton',
#  '2 tix 10 3 frozen furi xvii lo angel king v avalanch 103 row aa mgm grand',
#  'bet didnt know kick box',
#  'littl piec wrote avalanch design blog id appreci greatli check',
#  'patrick roy 1998 99 upper deck spx finit 1620 made colorado avalanch mint',
#  'musician kall mattson recreat 34 classic album cover clever music video avalanch',
#  'beauti sweet avalanch faith akito rose lot frothi gyp',
#  '1 6 tix calgari flame vs col avalanch preseason 9 29 scotiabank saddledom',
#  'secret avalanch catech inner self confidenti commun respect creat worth len',
#  'fall leav poplar fulli ordain tumbl avalanch spurgeon',
#  'saw two great punk band make origin music last week check em',
#  'great perform chip fuel ga saver chevi taho blazer avalanch 10',
#  'musician kall mattson recreat 34 classic album cover clever music video avalanch',
#  'drive avalanch car week like drive tank',
#  'free ebay snipe rt chevrolet avalanch ltz lift 4x4 truck pleas favorit amp share',
#  'chiasson sen cant come deal',
#  'paul rudd emil hirsch david gordon green princ avalanch q amp filmmak googl',
#  'great one time deal avalanch music purchas get neal rigga shirt',
#  'draft 2005 rd 4 overal play last season',
#  'got video rapper got song',
#  'yo flex im',
#  'avalanch one world away make believ im wide awak',
#  'possibl new jersey avalanch next year',
#  'feat watch incred music video',
#  'avalanch citi sunset',
#  'chevrolet avalanch lt 2011 lt use 5 3 l v 8 16 v automat 4 wd pickup truck premium b',
#  'snowflak avalanch ever feel respons',
#  'star war power jedi collect 1 battl droid hasbro full read ebay',
#  'civil war gener battl bull run hero colonel 2nd new hampshir letter sign',
#  'dragon ball z battl god 2014 rotten tomato via',
#  'ad video playlist world tank battl assist mod bat chat arti kaboom',
#  'ya boy clip vs 4ku full battl',
#  'inde fulli awar battl support fight',
#  'baaaack petersen bowhunt battl bow make sure head cast vote',
#  'want battl here war',
#  'kelbi tomlinson mild manner 2nd baseman great metropolitan team fight never end battl hit rbi way',
#  'black eye 9 space battl occur star m27329 involv 1 fleet total 1236 ship 7 destroy',
#  'realli happen taken king stori trailer space battl rip hole saturn',
#  'battl anim fuck much',
#  'see happen battl block final',
#  'gon get rap battl',
#  'thing battl intern vs extern motiv',
#  'check item got',
#  'young german stormtroop engag battl somm 1916',
#  'like video marvel vs dc aveng battl',
#  'sigh daili battl',
#  'ive come realiz dont attent span mass battl game paint play',
#  'interest see win battl',
#  'battl goat',
#  'star war power jedi collect 1 battl droid hasbro full read ebay',
#  'black eye 9 space battl occur star o784 involv 2 fleet total 4103 ship 50 destroy',
#  'rememb around australia descend grow via',
#  'miss gari busey son play dixi electron green fiddl post battl celebr sequenc',
#  'news fedex longer transport bioterror germ wake anthrax lab mishap',
#  'fedex longer transport bioterror germ via',
#  'usa today longer transport bioterror pathogen',
#  'fedex longer transport bioterror germ wake anthrax lab mishap via',
#  'jacksonvil busin fedex stop ship potenti bioterror pathogen',
#  'fedex longer transport bioterror pathogen wake anthrax lab mishap',
#  'respond fedex longer transport bioterror germ wake anthrax lab mishap',
#  'fedex longer transport bioterror germ wake anthrax lab mishap say fedex',
#  'fedex stop transport bioterror germ lab mishap fedex stop transport certain research',
#  'fedex longer ship potenti bioterror pathogen via',
#  'lab face secret sanction doesnt make cut',
#  'fedex longer transport bioterror germ wake anthrax lab mishap via',
#  'hous energi amp amp commerc subcommitte hold 7 28 hear cdc oversight bioterror lab armi anthrax mishap htt',
#  'fedex will transport research specimen potenti bioterror pathogen wake anthrax lab mishap',
#  'fedex longer transport bioterror germ wake anthrax lab mishap',
#  'fedex longer transport bioterror germ wake anthrax lab mishap',
#  'rt alisonannyoung exclus fedex longer transport research specimen bioterror pathogen wake anthrax lab mishap',
#  'hmm could problem research fedex longer transport select agent via',
#  'fedex longer transport bioterror germ wake anthrax lab mishap',
#  'fedex longer transport bioterror germ wake anthrax lab mishap',
#  'fedex longer ship potenti bioterror pathogen fedex corp nyse fdx longer deliv packag',
#  'fedex longer ship potenti bioterror pathogen atlanta busi chronicl',
#  'thank longer ship live microb depart defens',
#  'bioterror manufactur fear state repress',
#  'fedex longer transport bioterror germ via',
#  'fedex stop ship potenti bioterror pathogen',
#  'usatoday today lab face secret sanction doesnt make cut foxnew',
#  'fedex longer will transport research specimen potenti bioter',
#  'fedex longer transport bioterror germ wake anthrax lab mishap via',
#  'fedex stop ship potenti bioterror pathogen',
#  'fedex longer transport bioterror germ wake anthrax lab mishap',
#  'longer transport bioterror germ wake anthrax lab mishap',
#  'fedex longer ship bioterror germ wxia tv',
#  'fedex longer transport bioterror germ wake anthrax lab mishap',
#  'usatoday today lab face secret sanction doesnt make cut foxnew',
#  'fedex longer transport bioterror germ wake anthrax lab mishap via',
#  'biolab safeti concern grow fedex stop transport certain specimen research facil dumbfound action',
#  'fight bioterror sir',
#  'like video fema region iii target bioterror nasa japan rocket launch lithium',
#  'cdc carri extens review lab safeti pathogen handl procedur',
#  'firepow lab autom fight infecti diseas bioterror',
#  '90blk amp 8wht collud 2 take wht f auth hostag amp 2 make look blk w bioterror amp use lgl org idi id still',
#  'great iran deal cover bioterror got cut terribl keep good work',
#  'tale two pox bodi horror',
#  'bioterror public health superbug biolab epidem biosurveil outbreak homeland secur news wire',
#  'creation ai climat chang bioterror mass autom workforc contact life wealth inequ yea weve got easi',
#  'lie trust cia hollywood bioterror len horowitz vaccin nwo',
#  'satan daughter shadow warrior 50ft women aka transgend mode ps nyc fold extra extra center bioterror',
#  'ye would think sinc colleg 88 92 difficult think bioterror esp bc dispers',
#  'volunt need particip emerg prepared drill simul bioterror disast',
#  'major american newspap run seri alleg bioterror research go 2 n',
#  'fight bioterror sir',
#  'cdc pretti cool list bioterror agent 3',
#  'govern expert concern possibl bioterror use gm organ scientist concern',
#  'prepar us hh select 9 region special treatment center',
#  'support sy 4 auth taken hostag blk us clergyforc 2 exist younger amp grossli disfigur bioterror',
#  '70 70 amp think possibl full transform imposs dont quit like medic mysteri bioterror suck',
#  'fight bioterror sir',
#  'book describ futur therapi technolog sport sexual bioterror diagnosi',
#  'w ugli due 2 ugli frat bioterrorismim who id u tolewantg anoth home',
#  '90blk amp 8wht collud 2 take wht f auth hostag amp 2 make look blk w bioterror amp use lgl org idi id still',
#  'fight bioterror sir',
#  '90blk amp 8wht collud 2 take wht f auth hostag amp 2 make look blk w bioterror amp use lgl org idi id still',
#  '74 75 bioterror 2 evad lgl effort 2 prosecut blk 4 kidnapg',
#  'cover nuclear activ bioterror iran broken least 27 agreement',
#  'threat anthrax cdc via',
#  'author allay fear ahead rio olymp equestrian test event via',
#  'crave u',
#  'ive pool day',
#  'know anyon look move hammond share list',
#  'life amazin time crazi nigga dey wanna blaze hate made took dedic n motiv',
#  'blaze bro',
#  'ye love',
#  'see virtual tour one list 547 fir st cannon beach list dorri caruana',
#  'pendleton media offic said fire base right horno blaze',
#  'welcom',
#  'love live blaze insid apt balconi',
#  'alrighti hit well blaze',
#  'blaze jay fuck dutch slave trade',
#  'hair poverti moment need get fade weekend get',
#  'properti loss california wildfir nearli doubl week old blaze rage',
#  'firefight battl blaze east cari condo build',
#  'nigga love hate',
#  'dont like babe lt 3 youll ball fun lan',
#  'like video minecraft skywar blaze que usa hack e flechada sinistra',
#  'dem blaze cover month ago chicago polic detain thousand black american interrog facil',
#  'yo got bar im even rapper',
#  'ugh blaze put calori pizza ok cool',
#  'pic blaze fort kid look like jackass stuffin face like',
#  'look like year write comput ahead',
#  'let know',
#  'im mad 420 name amp dont blaze',
#  'yeah know blaze blue dont twitter lol drew week ago',
#  'news new facebook page featur seek help person custom experi',
#  'shout blaze hottest dj sothwest',
#  'like video minecraft episod 2 blaze farm begin',
#  'properti loss wildfir nearli doubl week old blaze rage fire',
#  'work yet see new vela short blaze',
#  'total tweet fail beauti insid blaze',
#  'mixtap come promis goin right',
#  'huh leo start last year ever sinc peopl blaze back',
#  '3 bedroom 1 bath sale 29 palm ca youtub video',
#  'ye 2 gun',
#  'daem girl smooth asf c',
#  'say agre',
#  'bright amp blaze fireman birthday parti',
#  'real vibez radio blaze best vibez',
#  'montgomeri come blaze hot weather stay std yet anoth reject citi slogan',
#  'come join us tomorrow august 7 2015 transcend blaze trail diversifi world market',
#  'morgan silver dollar 1880 gem bu dmpl cameo rev blaze ms high grade full read',
#  'morgan silver dollar 1880 gem bu dmpl cameo rev blaze ms high grade full read',
#  'bowl got think damn ive blaze damn long',
#  'he blaze game best stealth skill yet noth beat silenc m4',
#  'bit pacquiao vs marquez 3 unfil blaze swarm onlin durvod',
#  'turn radio live amp 107 9 fm blaze hit',
#  '32 inch dynasti',
#  'im weapon master let go gun blaze',
#  'realli sadli come expect obama',
#  'shouout caus vocal blaze hot like weather she',
#  's3xleak ph0to 19yr old ash ladi festac town delta exp0s bbm 5 leak pictur',
#  'oh heart race temperatur blaze roof fifth harmoni',
#  'haha love',
#  'colorado spanish word mean reddish color dummi pronounc wrong',
#  'traffic freez cold blaze hot heat traffic',
#  'im crazi enough run 95 degre mid day heat blaze sun place im',
#  'im blaze rn there noth stop',
#  'still blaze',
#  'thank sweat bullet everi time get blaze sun beat',
#  'blaze',
#  'lost word made new fan fam crazi skill beyond bless keep blaze dude made love respect',
#  'let hot blaze fantasi',
#  'thank missi thought suit blaze hot summertim yee haw',
#  'magic bag blaze',
#  'blaze elwood dont bother doug song tune',
#  'morgan silver dollar 1921 p ch gem bu pl blaze ms satin rare proof like full',
#  'blaze hot etisalat free mb complet 12 month etisalat give 100mb tecno q1 ime',
#  'want full bitch slap gun blaze cake throw charl showdown worth wait',
#  'follow check hit singl unpack man blaze',
#  'still dont know 8 hour physic activ blaze sun isnt sport',
#  'way archetyp bleed well ground readi fpoj',
#  'threw chicken nugget sister lip bleed',
#  'could slit throat id apolog bleed',
#  'joe landolina gel make stop bleed instantli',
#  'nose bleed last one like 10 year ago',
#  'bleed typewrit day far ive written bunch gunk',
#  'cant help hope your ok text need talk send hug way ps bleed death allow',
#  'stab back promis youll one bleed',
#  'appar your bleed peopl look weird lol well fine keep walk',
#  'eat taki rub eye hand eye bleed tear',
#  'yea heard come 2017 2019 vampiro bleed',
#  'look broken bleed',
#  'hit foot toe bleed',
#  'long see madara bleed im good',
#  'keep think step broken glass pun tak sedar dont feel pain also bleed shit',
#  'ear bleed',
#  'wait 2 5 hour get cab feet bleed',
#  'cute dinner date til cam nose start bleed',
#  'head like yo nose bleed',
#  'ive bleed silenc feel safer violenc',
#  'fell someon back hit head concret bleed n shit',
#  'ye im bleed heart liber',
#  'deadpool alreadi one favourit marvel charact know wear red suit bad guy cant tell he bleed',
#  'def stop bleed',
#  'know u your bleed heart wannab pickup artist',
#  'awesom saw bleed pretti bad',
#  'bleed brain dont know caus',
#  'let see good soccer your bleed yo face',
#  'bleed wild thing run around apart he work bar',
#  'bleed instinct kick look away scratch back head',
#  'ear bleed hate stefano',
#  'ear start bleed',
#  'saw pileup tv keep race even bleed',
#  'rave wed see eye bleed',
#  'say bad thing happen reason wise word gonna stop te bleed',
#  'yo timelin blew damn fast',
#  'go look blew w atom bomb',
#  'blew instagram caus she cute she activ follow',
#  'see crazi line blew',
#  'instagram blew appar featur jazz tonight cool love',
#  'id still team usagi even blew entir solar system airhead misstep',
#  'rememb u like 4 0 blew one game u prob dont king cup',
#  'hate peopl tweet receipt know wrong wont take bc blew liter gtfo your desper',
#  'think blew notif go check she encourag love',
#  'hw18 go 90 100 dude keep took exit pull side told blew motor lolol',
#  'univers might actual exist scientist say blew began',
#  'max blew tf shot fire',
#  'rick morti blew',
#  'ty blew motor went flame got ok',
#  'realiz dude way blew tuski game',
#  'night blew rq',
#  'blew snapchat reason',
#  'queen gambit went well anakin blew droid control ship oh well still fun cant stop next',
#  'iron michel bachmann brought 11 w ron paul amp everyon blew call hoax final right',
#  'catfish retweet amp notif blew',
#  'guy whistl park lot amp help wind blew skirt get car',
#  'blew mention',
#  '1st time someon blew phone 30 time would block believ',
#  'like liter blew',
#  'freya video blew everywher',
#  'easi way look good ray rice fiasco blew',
#  'lmao light skin guy blew twitter talk ugli kid',
#  'watch honey blew economi recommend conserv shopp horror',
#  'anyon els see firebal fall earth look like plane blew',
#  'ye thing big sean still blew',
#  'zayn blew twitter',
#  'bitch done blew shit',
#  'damn clue tri see mani click could get blew that play',
#  'great pair like coupl graywarden fight blight',
#  'there actual theori magist arent reason blight dwarv one',
#  'cycl fan feel sorri world athlet blight exacerb monetari reward lot soul search requir',
#  'blight',
#  'poor jack',
#  'agre knew wed go deep road found blight red lyrium aint yet gt gt',
#  'get load welfar love spong blight societi',
#  'new post prysmian secur contract blight bank wind farm',
#  'cleveland height shaker height fight blight hous next door',
#  'want see info blight u got',
#  'carl everest rob cobe whitt blight frost leo snuff godli other drink beer someday',
#  'thda kick anti blight loan effort memphi',
#  'citi program help turn blight greenspac tennesse hous develop',
#  'ye want new blight leader',
#  'releas plane level 1 constel blight gaia iclown drumstep remix 2 iclown infin',
#  'cleveland height shaker height fight blight hous next door',
#  'go achiev excel big thing develop habit littl matter dont know author',
#  'sure purdi aliv blight',
#  'traci blight thank follow',
#  'appercept bridgework blight xxhjesc',
#  'dotish blight car go right ahead mine',
#  'sexual revolut blight women stori via',
#  'like swear secret well uncov old god slumber think there gonna anoth blight',
#  'doubl result live app',
#  'first one want use commun never ask blight park',
#  'look polici matter ohio report cuyahoga counti blight green vacant land soon',
#  'put taint magist open gate let blight get away',
#  'theori make way much sens say dwarv may actual origin blight',
#  'tragedi blight human amp shame everi live',
#  'articl michael jackman metro time detroit group later downgrad estim 37 squar mile',
#  'locksmith art respect elabor blight lock lpdkl',
#  'cunt',
#  'everi 5000 win rank play gave special card back would cool long te',
#  'amazon deal wait buy',
#  'new print avail wait long pamela blizzard',
#  'give free art kamon',
#  'order blizzard pay put nut say ball flavor boom free ice cream',
#  'blizzard auz 9 pm cst 2 hr rock make hump day complet',
#  'realli want rolo blizzard mom said guess dq tonight',
#  'hi ashayo believ vod youtub present noth like see live',
#  'stat',
#  'dolphin worship group base superstit take look tweet',
#  'lucio let get hype train roll caution though arent break',
#  'ight',
#  'peanut butter cooki dough blizzard',
#  'mic control arent work one second',
#  'tomorrow announc vod',
#  'updat window 10 get error',
#  'new expans idea bard class holi triniti 1',
#  'realli shock blizzard lure old fanbas back wod disappoint us hardcor everyon leav',
#  'best thing dq cotton candi blizzard',
#  'lizard wizard blizzard',
#  'need',
#  'pleas blizzard love',
#  'blizzard would clutch asf',
#  'also pleas would much like link',
#  'ok ok okayyyyyi ima act right bout get blizzard tho',
#  'control tora',
#  'first time play hearthston pc thought',
#  'love cotton candi blizzard',
#  'hard reset xbox',
#  'realli wanna browni batter blizzard',
#  'call littl bit blizzard',
#  'market news activis blizzard cogniz technolog first solar',
#  'sean end career sg blizzard vs knockout',
#  'biggest regret hearthston',
#  'someon walk dq wanna butterfing blizzard bad',
#  'horribl moment u open dryer look like snowi blizzard cuz u left piec paper jean pocket',
#  'bruh die',
#  'rip blood',
#  'nah young blood cook gone im cut haha',
#  'wall invinc histori blood danc floor',
#  'broke nail real fake morn blood ah hurt idea treat help pretti pleas',
#  '4 5 5 star 290 review dragon blood boxset lindsay burok',
#  'blood group associ gastric carcinoma say text book anoth fragil gene bodi',
#  'friend like blood besid us alway come wound',
#  'gone get get blood',
#  'peopl u allow donat blood receiv blood well',
#  'dialys grandpa oh lord blood make light head',
#  'dad dont claim mean right look eye blood xbox 360 smh',
#  'omron hem 712c automat blood pressur monitor standard larg bp cuff',
#  'blood pressur roof dont need extra shit',
#  'yeah',
#  'cant believ peopl mid 20 dont high blood pressur life stress',
#  'guy imouto isnt actual relat blood',
#  'bruh white peopl buy ugliest shoe super tight blood go feet',
#  'anoth day anoth excel porridg serious peopl blood orang porridg phenomen',
#  'happi birthday young blood',
#  'wasnt blood',
#  'kinda shii nasti blood pun intend',
#  'aint hoe blood',
#  'today hastl get drug test blood drown tb shot document fill',
#  'man somebodi gotta stop sbee dude fuckin funni blood',
#  'wind take gypsi blood time',
#  'mad men',
#  'privat thirsti night sad blood rockn roll',
#  'elli gould blood acess nosso site para ouvir',
#  'welcom read free chapter new book encount jesu full hope',
#  'run blood',
#  'person favorit includ paramor muse green day royal blood 5so',
#  'shed innoc blood son daughter land pollut psalm 106 38 help stop sin abort',
#  'se pone cantar cri lightn',
#  'wasnt big stab deep stab there like blood everwh',
#  'add item everyday eat habit pleas research take blood',
#  'looooooooooool bloodi hell',
#  'infect bloodi ear pierc alway fun',
#  'aggressif bloodi aggress',
#  'enter entir set butterlondon lip crayon via go enter',
#  'hey salli sorri email awol bloodi work argh',
#  'im listen bloodi jay',
#  'forrest version 83 that bloodi aw well xxx',
#  'nightmar elm street get remad',
#  'cant bloodi wait soni set date stephen king dark tower',
#  'gotta tri let go mani bloodi thing smh',
#  '1 russia may play reason link bs okanowa bloodi mainlin invas look like bloodi',
#  'bloodi insomnia grrrr',
#  'tri 11 eye akam ga kill tokyo ghoul damn bloodi dont dare watch',
#  'suck that your bloodi get mean amend',
#  'call weekend call bloodi mari time summer full new',
#  'bloodi hell day havent even realli done anyth tire everyth thought vaca would help much',
#  'damn bloodi hot',
#  'bloodi sexi drool',
#  'know say side effect low amp realli fast son product acn cream 1 side effect bloodi diarrhea',
#  'ronda rousey would close make floyd mayweath money 50 fight bloodi elbow',
#  'im aw paint agre a3 landscap bloodi oil paint',
#  'need life sin girlfriend ride till bloodi end girlfriend',
#  'think well bloodi bark',
#  'eh hello cover bloodi thigh bloodi cleav eh hello sinc expos cleavag',
#  'mega bloodi marvel',
#  'bloodi mari sink beet juic',
#  'monti python date bloodi far want go',
#  'meet bloodi rs5',
#  'friday suppos happi day bloodi friday hah zzzz',
#  'bloodi hope said fold arm sit back chair',
#  'wait tell colleg friend reaf bloodi mari drama cd',
#  'came kill indian fun video smirk remorseless pakistani killer show boast',
#  'ive watch episod s01e09 bloodi monday',
#  'marlon william gt elvi presley gt marlon william gt steel panther shuffl mode like bloodi legend',
#  'black friday turn bloodi would rather shop',
#  'someon told soccer mom get pic blown put daughter bedroom wall',
#  's2g mention get blown choic deactiv leav good respect choic',
#  'wow wow club blown money fuck player like theyd pillori',
#  'damn greink got blown first inning',
#  'woke blown lol',
#  'aunt marg your blown ehek',
#  'yeah worth bc alreadi mani spammer amp twitter probabl blown everi second',
#  'white famili supposedli repres america great valu get blown horribl cgi nuclear strike lmfaoooo',
#  'man hasnt blown he still underground',
#  'mention blown wtf',
#  '1862 confeder ship blown crew read via',
#  'moment ur win mini uhc get blown creeper get kick fli salti rn',
#  'get bump approv probabl he blown',
#  'truckload soldier blown nobodi panic one littl lion die everyon lose mind',
#  'hey look kash foundat live today got blown peopl magazin websit todd blake',
#  'got last month went ee shop glad hasnt blown yet',
#  'first time tweet blown almost half day later',
#  'blown away extens noth seen mani option one',
#  'thank let stay sinc manor blown anyway buddi',
#  'loner diari pattern sand may blown away photo two choke flame',
#  'even though bsg suffici hype year somehow delay watch utterli utterli blown away',
#  'vanessa game offici blown ladi gentlemen real show begin',
#  'guarante bitten mutant mosquito ankl blown littl cunt',
#  'thing pick tozlet seat butt leprosi full blown jerkfac syndrom later lisp amp toilet ricket',
#  'ig blown hacker need stop',
#  'whoever direct video need grab nicki minaj someon u recognit mind blown',
#  'last week want 6th sens get blown far good jame could win he huge target gone soon',
#  'like blown amirit',
#  'dog blown kennel bloodi yorkshir terrorist',
#  'turn espn2 get blown',
#  'went beaten blown next thing know ra al ghul brought back life escap',
#  'leo ass got metaphor blown',
#  'glononium 6c also help blown bash bottl nitroglycerin book',
#  'new ladi shoulder tote handbag women cross bodi bag faux leather fashion purs full',
#  'new ladi shoulder tote handbag women cross bodi bag faux leather fashion purs full',
#  'son daughter would like see go war iran come back bodi bag let know',
#  'ditto way feel drank vodka ice would bodi bag',
#  'handbag genuin mulberri antoni cross bodi messeng bag dark oak soft buffalo leather 279 00end date w',
#  'loui vuitton monogram sophi limit edit clutch cross bodi bag full read ebay',
#  'loui vuitton monogram sophi limit edit clutch cross bodi bag full read ebay',
#  'loui vuitton cultsierr monogram shoulder bag cross bodi bag',
#  'check ameribag healthi back bag shoulder cross bodi backpack khaki tan beig nylon',
#  'photo bath amp bodi work cosmet bag periwinkl blue copper pipe along top four corner',
#  'new ladi shoulder tote handbag women cross bodi bag faux leather fashion purs full',
#  'new summer long thin bodi bag hip word skirt blue',
#  'new ladi shoulder tote faux leather hobo purs cross bodi bag rt en',
#  'bruh wanna fight im meet cage bro better find your deal end bodi bag',
#  'new ladi shoulder tote handbag faux leather hobo purs cross bodi bag women full read',
#  'auth loui vuitton brown saumur 35 cross bodi shoulder bag monogram 7 23 419 3 full read',
#  'check vintag longaberg floral fabric shoulder cross bodi bag brown leather strap',
#  'new ladi shoulder tote faux leather hobo purs cross bodi bag',
#  'new summer long thin bodi bag hip word skirt blue',
#  'new ladi shoulder tote faux leather hobo purs cross bodi bag rt en',
#  'loui vuitton monogram sophi limit edit clutch cross bodi bag full read ebay',
#  'new women handbag faux leather ladi shoulder tote cross bodi bag larg satchel full',
#  'new ladi shoulder tote faux leather hobo purs cross bodi bag',
#  'one day heart gone get zip bodi bag',
#  'authent loui vuitton pochett bosphor shoulder cross bodi bag',
#  'new ladi shoulder tote faux leather hobo purs cross bodi bag',
#  'vintag coach purs camera bag cross bodi 16 99 0 bid',
#  'genuin leather man bag messeng fit ipad mini 4 tablet case cross bodi air jp full rea',
#  'loui vuitton monogram sophi limit edit clutch cross bodi bag full read ebay',
#  'new ladi shoulder tote faux leather hobo purs cross bodi bag',
#  'nuu fam fwt im leav bodi bag',
#  'new ladi shoulder tote handbag faux leather hobo purs cross bodi bag women full read',
#  'im im say theyr lucki go home famili put bodi bag',
#  'oh im bag bodi bangin im say she go get rose',
#  'bag bodi she smoke hot',
#  'drake realli bodi bag meek',
#  'drake kill dude tea bag dead bodi point',
#  'w rec k leagu ball olymp level bodi bag like career noth',
#  'idgaf tough canada north philli meek act like bitch amp drake bodi bag ass track',
#  'bodi bag mf',
#  'skim twitter miss bodi bag',
#  'g bodi bag lyric',
#  'straight bodi bag',
#  'bodi bag bitch',
#  'better feel see stage day one 22 year friendship still bodi bag mic togeth',
#  'mophem bigstar johnson problem game bodi bag nigga',
#  'bodi bag today 4got post score',
#  'let bag bodi begin lol aint cuf yet shouldnt bad',
#  ...]

# %%
cv = CountVectorizer()
X = cv.fit_transform(trainclean).toarray()
y = dftrain1["target"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
model = MultinomialNB()
model.fit(X_train, y_train)
y_pred=model.predict(X_test)
cf=classification_report(y_test,y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.86      0.81      1244
#            1       0.80      0.68      0.74      1040
#
#     accuracy                           0.78      2284
#    macro avg       0.78      0.77      0.77      2284
# weighted avg       0.78      0.78      0.78      2284

# %%
model1 = GaussianNB()
model1.fit(X_train, y_train)
y_pred=model1.predict(X_test)
cf=classification_report(y_test,y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.44      0.55      1244
#            1       0.54      0.79      0.64      1040
#
#     accuracy                           0.60      2284
#    macro avg       0.63      0.62      0.59      2284
# weighted avg       0.64      0.60      0.59      2284

# %%
model2 = DecisionTreeClassifier()
model2.fit(X_train, y_train)
y_pred=model2.predict(X_test)
cf=classification_report(y_test,y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.73      0.74      1244
#            1       0.68      0.69      0.69      1040
#
#     accuracy                           0.71      2284
#    macro avg       0.71      0.71      0.71      2284
# weighted avg       0.71      0.71      0.71      2284

# %%
model3 = LogisticRegression()
model3.fit(X_train, y_train)
y_pred=model3.predict(X_test)
cf=classification_report(y_test,y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.88      0.82      1244
#            1       0.82      0.67      0.74      1040
#
#     accuracy                           0.79      2284
#    macro avg       0.79      0.78      0.78      2284
# weighted avg       0.79      0.79      0.78      2284

# %%
model4 = RandomForestClassifier(n_estimators = 100)
model4.fit(X_train, y_train)
y_pred=model4.predict(X_test)
cf=classification_report(y_test,y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.82      0.78      1244
#            1       0.76      0.68      0.71      1040
#
#     accuracy                           0.75      2284
#    macro avg       0.75      0.75      0.75      2284
# weighted avg       0.75      0.75      0.75      2284

# %%
model5 = KNeighborsClassifier(n_neighbors = 3)
model5.fit(X_train, y_train)
y_pred=model5.predict(X_test)
cf=classification_report(y_test,y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.54      0.61      1244
#            1       0.57      0.72      0.64      1040
#
#     accuracy                           0.62      2284
#    macro avg       0.63      0.63      0.62      2284
# weighted avg       0.64      0.62      0.62      2284

# %%
model6 = RidgeClassifier()
model6.fit(X_train, y_train)
y_pred = model6.predict(X_test)
cf = classification_report(y_test, y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.85      0.80      1244
#            1       0.78      0.67      0.72      1040
#
#     accuracy                           0.76      2284
#    macro avg       0.77      0.76      0.76      2284
# weighted avg       0.77      0.76      0.76      2284

# %% [markdown]
# ### Seems like GaussianNB and KNN have the worst scores by far, so we'll drop those from further analysis.

# %% [markdown]
# ### Run the models with the PorterStemmer and TfidfVectorizer

# %%
tf = TfidfVectorizer()
X1_idf = tf.fit_transform(trainclean).toarray()
y1 = dftrain1["target"]
X_train, X_test, y_train, y_test = train_test_split(X1_idf, y1, test_size=0.3)

# %%
model = MultinomialNB()
model.fit(X_train, y_train)
y_pred=model.predict(X_test)
cf=classification_report(y_test,y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.91      0.83      1283
#            1       0.85      0.65      0.74      1001
#
#     accuracy                           0.80      2284
#    macro avg       0.81      0.78      0.79      2284
# weighted avg       0.81      0.80      0.79      2284

# %%
model1 = DecisionTreeClassifier()
model1.fit(X_train, y_train)
y_pred=model2.predict(X_test)
cf=classification_report(y_test,y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.72      0.73      1283
#            1       0.66      0.68      0.67      1001
#
#     accuracy                           0.70      2284
#    macro avg       0.70      0.70      0.70      2284
# weighted avg       0.71      0.70      0.71      2284

# %%
model2 = LogisticRegression()
model2.fit(X_train, y_train)
y_pred=model3.predict(X_test)
cf=classification_report(y_test,y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.91      0.83      1283
#            1       0.85      0.63      0.73      1001
#
#     accuracy                           0.79      2284
#    macro avg       0.80      0.77      0.78      2284
# weighted avg       0.80      0.79      0.78      2284

# %%
model3 = RandomForestClassifier(n_estimators = 100)
model3.fit(X_train, y_train)
y_pred=model4.predict(X_test)
cf=classification_report(y_test,y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.85      0.80      1283
#            1       0.77      0.67      0.71      1001
#
#     accuracy                           0.77      2284
#    macro avg       0.77      0.76      0.76      2284
# weighted avg       0.77      0.77      0.76      2284

# %%
model4 = RidgeClassifier()
model4.fit(X_train, y_train)
y_pred = model6.predict(X_test)
cf = classification_report(y_test, y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.86      0.81      1283
#            1       0.79      0.67      0.72      1001
#
#     accuracy                           0.78      2284
#    macro avg       0.78      0.77      0.77      2284
# weighted avg       0.78      0.78      0.77      2284

# %% [markdown]
# ### Running the models with a lemmatizer and Count Vectorizer

# %%
lemma = WordNetLemmatizer()
stop_words = stopwords.words("english")
def clean_tweet2(X6):
    if type(X6) == np.float:
        return ""
    tweet = X6.lower()
    tweet = re.sub("'", "", tweet) 
    tweet = re.sub("@[A-Za-z0-9_]+","", tweet)
    tweet = re.sub("#[A-Za-z0-9_]+","", tweet)
    tweet = re.sub(r'http\S+', '', tweet)
    tweet = re.sub('[()!?]', ' ', tweet)
    tweet = re.sub('\[.*?\]',' ', tweet)
    tweet = re.sub("[^a-z0-9]"," ", tweet)
    tweet = tweet.split()
    tweet =[lemma.lemmatize(word) for word in tweet if (word not in stop_words)]
    tweet = " ".join(word for word in tweet)
    
    return tweet

# %%
X6 = dftrain1["text"]
trainclean1 = [clean_tweet2(tw) for tw in X6]
trainclean1
# Out:
# ['deed reason may allah forgive u',
#  'forest fire near la ronge sask canada',
#  'resident asked shelter place notified officer evacuation shelter place order expected',
#  '13 000 people receive evacuation order california',
#  'got sent photo ruby smoke pours school',
#  'update california hwy 20 closed direction due lake county fire',
#  'heavy rain cause flash flooding street manitou colorado spring area',
#  'im top hill see fire wood',
#  'there emergency evacuation happening building across street',
#  'im afraid tornado coming area',
#  'three people died heat wave far',
#  'haha south tampa getting flooded hah wait second live south tampa gonna gonna fvck',
#  '18 19 day ive lost count',
#  'bago myanmar arrived bago',
#  'damage school bus 80 multi car crash',
#  'whats man',
#  'love fruit',
#  'summer lovely',
#  'car fast',
#  'goooooooaaaaaal',
#  'ridiculous',
#  'london cool',
#  'love skiing',
#  'wonderful day',
#  'looooool',
#  'way cant eat shit',
#  'nyc last week',
#  'love girlfriend',
#  'cooool',
#  'like pasta',
#  'end',
#  'wholesale market ablaze',
#  'always try bring heavy',
#  'breaking news nigeria flag set ablaze aba',
#  'cry set ablaze',
#  'plus side look sky last night ablaze',
#  'theyve built much hype around new acquisition doubt set epl ablaze season',
#  'inec office abia set ablaze',
#  'barbados jamaica two car set ablaze santa cruz head st elizabeth police superintende',
#  'ablaze lord',
#  'check',
#  'outside youre ablaze alive youre dead inside',
#  'awesome time visiting cfc head office ancop site ablaze thanks tita vida taking care u',
#  'soooo pumped ablaze',
#  'wanted set chicago ablaze preaching hotel',
#  'gained 3 follower last week know stats grow',
#  'west burned thousand wildfire ablaze california alone',
#  'building perfect tracklist life leave street ablaze',
#  'check',
#  'first night retainer quite weird better get used wear every single night next year least',
#  'deputy man shot brighton home set ablaze',
#  'man wife get six year jail setting ablaze niece',
#  'santa cruz head st elizabeth police superintendent lanford salmon r',
#  'police arsonist deliberately set black church north carolina ablaze',
#  'noches el bestia happy see teammate training hard goodnight gunner',
#  'trampling turkmen flag later set ablaze others vandalized office turkmen front',
#  'truck ablaze r21 voortrekker ave outside tambo intl cargo section',
#  'set heart ablaze every city gift every skyline like kiss upon lip',
#  'sky ablaze tonight los angeles im expecting ig fb filled sunset shot know peep',
#  'west burned thousand wildfire ablaze alone',
#  'revel wmv video mean mac farewell ablaze wmv en route dvd gtxrwm',
#  'progressive greeting month student would set pen ablaze torch publication',
#  'rene ablaze amp jacinta secret 2k13 fallen sky edit mar 30 2013',
#  'steve fire something else california tinderbox clown setting hood ablaze',
#  'rene ablaze amp ian buff magnitude',
#  'huge fire wholesale market ablaze',
#  'time talk go dont know make due work',
#  'cant kid cuz got bicycle accident amp split testicle impossible kid michael father',
#  'accident 24 w traffic moving 8m slower usual',
#  'accident center lane blocked u 101 nb great america pkwy',
#  'accident summer read advice amp see help',
#  'speeding among top cause teen accident car accident tee',
#  'reported motor vehicle accident curry herman rd near stephenson involving overturned vehicle please use',
#  'bigrigradio live accident awareness',
#  '77 mile marker 31 south mooresville iredell vehicle accident ramp closed 8 6 1 18 pm',
#  'rt sleeping pill double risk car accident',
#  'accident knew gon happen',
#  'traffic accident n cabrillo hwy magellan av mir 08 06 15 11 03 58',
#  '77 mile marker 31 40 south mooresville iredell vehicle accident congestion 8 6 1 18 pm',
#  'pastor scene accident owner range rover',
#  'mom didnt get home fast wished mom accident truck spilt mayonnaise',
#  'horrible car accident past sunday im finally able get around thank god',
#  'wait see pissed donnie tell another accident',
#  'overturn interstate click youve crash gt',
#  'accident u 23 sb sr 752',
#  'carolina accident motorcyclist dy 540 crash car crossed median motorcycle rider traveling',
#  'fyi cad fyi accident property damage nh 999 piner rd horndale dr',
#  'rt naayf first accident year turning onto chandanee magu near mma taxi rammed halfway turned everyone conf',
#  'accident left lane blocked rt 293 nb eddy rd stop go traffic back nh 3a delay 4 min',
#  'accident property damage piner rd horndale dr',
#  'accident',
#  'fyi cad fyi accident property damage wpd 1600 17th st',
#  '8 6 2015 09 pm traffic accident injury 2781 willis foreman rd',
#  'aashiqui actress anu aggarwal near fatal accident',
#  'suffield alberta accident',
#  '9 mile backup 77 south accident blocking right 2 lane exit 31 langtree rd consider nc 115 nc 150 nc 16 alternate',
#  'accident changed life help determine option financially support life care plan going treatment',
#  'deadly motorcycle car accident happened today ill detail 5',
#  'marinading accident',
#  'car even week got fucking car accident mf cant fucking drive',
#  'police previously died road accident killed explosion',
#  'still heard church leader kenya coming forward comment accident issue disciplinary measure',
#  'scuf p live game cya',
#  'man drive effort get painful man win roger bannister',
#  '320 icemoon',
#  'victory bargain basement price dwight david eisenhower',
#  '320 icemoon',
#  'nobody remembers came second charles schulz',
#  'im speaking someone using scuf xb1 people end getting p also',
#  'harder conflict glorious triumph thomas paine',
#  'going clay pigeon shooting cry aftershock',
#  'guess one actually want free aftershock tc',
#  'aftershock terrifying best roller coaster ive ever disclaimer ive',
#  'aftershock',
#  '320 icemoon',
#  '320 icemoon',
#  '320 icemoon',
#  'im seeing issue aftershock',
#  '320 icemoon',
#  '320 icemoon',
#  'bonus 5 minute daily habit could really improve life many already',
#  'aftershock protect profit next global financial meltdown david wiedemer http',
#  'moment get scary roller coaster guy behind screaming bloody murder',
#  'aftershock 2010 full streaming youtube',
#  'gt gt 15 aftershock protect profit next global financial',
#  'sometimes face difficulty youre something wrong youre something right joel osteen',
#  'thing stand dream try belief actually possible joel brown',
#  'praise god ministry tell like',
#  'remembering going die best way know avoid trap thinking something lose steve job',
#  'tried orange aftershock today life never',
#  'love bb',
#  'aftershock',
#  'aftershock back school kick great want thank everyone making possible great night',
#  'people say cannot done interrupt george bernard shaw',
#  'first man get oyster second man get shell andrew carnegie',
#  'anyone need p u tonight play hybrid slayer ps4 eu hmu',
#  'expert france begin examining airplane debris found reunion island french air accident expert',
#  'strict liability context airplane accident pilot error common component aviation cr',
#  'lifetime odds dying airplane accident 1 8015',
#  'expert france begin examining airplane debris found reunion island french air accident expert wedn',
#  'awwww theyre airplane accident theyre gonna die cuties good job',
#  'family member osama bin laden died airplane accident ironic mhmmm gov shit suspect',
#  'man go airplane engine accident via',
#  'horrible accident man died wing airplane 29 07 2015',
#  'cessna airplane accident ocampo coahuila mexico july 29 2015 killed four men including state coahuila government official',
#  'man died wing airplane 29 07 2015',
#  'expert france begin examining airplane debris found reunion island french air accident expert wednesday',
#  'expert france begin examining airplane debris found reunion island french air accident expert wednesday began examining',
#  'mbataweel family member killed airplane accident',
#  'almost sent coworker nude accident thank god airplane mode',
#  'might killed airplane accident night car wreck politics best',
#  'expert france begin examining airplane debris found reunion island french air accident expert',
#  'unbelievably insane',
#  'horrible accident man died wing airplane 29 07 2015',
#  'horrible accident man died wing airplane 29 07 2015',
#  'usama bin ladin family dead airplane crash naturally accident',
#  'pilot dy plane crash car festival via',
#  'strict liability context airplane accident',
#  'dtn brazil expert france begin examining airplane debris found reunion island french air accident exp',
#  'expert france begin examining airplane debris found reunion island french air accident expert wedn',
#  'horrible accident man died wing airplane 29 07 2015 wtf believe eye',
#  'nicole fletcher one victim crashed airplane time ago accident left little bit trauma although shes',
#  'omg horrible accident man died wing airplane',
#  'dont believe bro',
#  'expert france begin examining airplane debris found reunion island french air accident expert wednesday began examining',
#  'airplane accident',
#  'phone look like car ship airplane accident terrible',
#  'statistically im risk getting killed cop dying airplane accident',
#  'airplane crash house colombia 12 people die accident',
#  'shooting airplane accident',
#  'could drone cause airplane accident pilot worried use drone esp close vicinity airport',
#  'early wake call sister begging come amp ride w ambulance hospital',
#  'twelve feared killed pakistani air ambulance helicopter crash',
#  'two air ambulance scene serious crash two car lorry',
#  'twelve feared killed pakistani air ambulance helicopter crash reuters',
#  'leading emergency service bos welcome new ambulance charity',
#  'anyone travelling aberystwyth shrewsbury right there incident service halt outside shrew ambulance scene',
#  'twelve feared killed pakistani air ambulance helicopter crash',
#  'ambulance sprinter automatic frontline vehicle choice 14 lez compliant ebay',
#  'new nanotech device able target destroy blood clot',
#  'hella crazy 3 fight ambulance couple mosh pit',
#  'get run ambulance lucky',
#  'twelve feared killed pakistani air ambulance helicopter crash',
#  'twelve feared killed pakistani air ambulance helicopter crash',
#  'waiting ambulance',
#  'ok need ambulance hahahah good',
#  'ambulance sprinter automatic frontline vehicle choice 14 lez compliant ebay',
#  'pakistan air ambulance helicopter crash kill nine',
#  'nissan ok need medical assistance call ambulance need',
#  'ems1 ny emts petition 17 per hour minimum wage',
#  'twelve feared killed pakistani air ambulance helicopter crash',
#  'twelve feared killed pakistani air ambulance helicopter crash',
#  'ambulance sprinter automatic frontline vehicle choice 14 lez compliant ebay',
#  'ambulance sprinter automatic frontline vehicle choice 14 lez compliant ebay',
#  'check whats parking lot said last year ambulance st john',
#  'dont know way ambulance coming lt lt',
#  'twelve feared killed pakistani air ambulance helicopter crash',
#  'twelve feared killed pakistani air ambulance helicopter crash',
#  'ambulance right outside work',
#  'dog think he ambulance',
#  'happening hatzolah em ambulance responding dual siren',
#  'twelve feared killed pakistani air ambulance helicopter crash',
#  'twelve feared killed pakistani air ambulance helicopter crash',
#  'twelve feared killed pakistani air ambulance helicopter crash',
#  'twelve feared killed pakistani air ambulance helicopter crash',
#  'whats police ambulance number lesotho body know',
#  'surprised still cannot standardised clinical practice across 11 nh ambulance trust',
#  'twelve feared killed pakistani air ambulance helicopter crash',
#  'people try j walk ambulance passing hate',
#  'episode trunk annihilated freiza cleanest shit ever showed nigga mercy',
#  'shall annihilated petebests dessicated laid bare shall kneel',
#  'uribe annihilated baseball',
#  'hey sundown annihilated previous meeting celtic indeed improvement',
#  'mizzou annihilated florida past 2 season even ended muschamps career cant compete bama',
#  'annihilated ab',
#  'annihilated status education mba behalf easy street careen eovm',
#  'luka die everything annihilated alois trancy',
#  'good un fella sorry wont get annihilated',
#  'cop pull drunk driver safety second car hit train via',
#  'must annihilated',
#  'cop pull drunk driver safety second car hit train via',
#  'boom country entirely annihilated h britain',
#  'would annihilated might well thank',
#  'one thing sure god promised israel annihilated horror iran w nuke',
#  'guess thats ok armenian since weve spent history getting annihilated',
#  '70 year since annihilated 100000 people instantly became aware ability annihilate whole humanity',
#  'day 1 tryout went good minus fact stopped quickly get short ball annihilated toenail injury even',
#  '1960s oryx symbol arabian peninsula annihilated hunter',
#  'luka die everything annihilated alois trancy',
#  'ready get annihilated bucs game',
#  'people annihilated last night weather really philip thought would forecast',
#  'domain sophistication annihilated closely minute feat zrnf',
#  'seen juda priest 2005 rob came back scorpion support fucking annihilated place astonishing gig',
#  'officially skipping whatever hashtag getting annihilated review bummer',
#  'thus explaining annihilated case survivor evolved became godlike',
#  'completely annihilated cech paul keegan time alive',
#  'annihilated legion survivor imperfect hybrid project quickly formed new secret cell',
#  'exactly thats lesnar cena match summerslam last year great brock annihilated guy who',
#  'cop pull drunk driver safety second car hit train via',
#  'annihilated damascus syrian army grind alloosh gang manure pile',
#  'ok wasnt completely forthright may also food coma bc kebab tahini pickle also annihilated w fry',
#  'fun filled happy hour simmons bar camden handsome one got annihilated apart game',
#  'juanny beisbol sr annihilated ball',
#  'hell fraction belief total annihilation destruction usa',
#  'maybe call israel tell sorry pres sold river annihilation',
#  'evildead annihilation civilization',
#  'u national park service tonto national forest stop annihilation salt river wild horse via',
#  'annihilating quarterstaff annihilation',
#  'world annihilation v self transformation alien attack exterminate human',
#  'starmade stardate 3 planetary annihilation via',
#  'u national park service tonto national forest stop annihilation salt river wild horse via',
#  'u national park service tonto national forest stop annihilation salt river wild horse via',
#  'please sign share petition save wild horse arizona',
#  'u national park service tonto national forest stop annihilation salt river wild horse via',
#  'please check salt river horse help stop annihilation happen without 54000 signature change org thx',
#  'soul punished annihilation',
#  'mention major contributor annihilation israel',
#  'need help horse die please rt amp sign petition take stand amp voice',
#  'reject law misguided false prophet imprison nation fueling self annihilation',
#  'u national park service tonto national forest stop annihilation salt river wild horse via',
#  'annihilation jeb christie amp kasich le 24 hour away please god allow least one full day',
#  'need help horse die please rt amp sign petition take stand amp voice',
#  'need help horse die please rt amp sign petition take stand amp voice',
#  'hey sign petition save sing long order',
#  'stop annihilation salt river wild horse via',
#  'he current nova bookslast checked tied book 2011 rider died annihilation',
#  'u national park service tonto national forest stop annihilation salt river wild horse via',
#  'please sign amp rt save',
#  'thanks dante join u following zone johnny',
#  'world annihilation v self transformation alien attack exterminate human',
#  'u national park service tonto national forest stop annihilation salt river wild horse via',
#  'u national park service tonto national forest stop annihilation salt river wild horse via',
#  'im gonna fight taylor soon get',
#  'ohh fukurodani didnt survive apocalypse bokuto feel horrible poor boy ppor child',
#  'another jocelyn birthday apocalypse',
#  'rt janenelson097 rt stephenscifi adaptation watch charlie human apocalypse optioned film',
#  'apocalypse please',
#  'another hour august 05 2015 08 02pm here red rover zombie apocalypse 2014',
#  'feel like pull one stage apocalypse',
#  'shes kinda hot played radio today whats next disease apocalypse started everyone careful',
#  'apocalypse lol gf m8',
#  'know question interpretation sign apocalypse called',
#  'julie r apocalypse version romeo juliet',
#  'apocalypse upon u',
#  'rt fittscott minecraft night lucky block mod bob apocalypse wither 2 0 amp mod showcase popularmmos vi',
#  'begin day one snow apocalypse',
#  'rt mother mary short reading apocalypse 21 1023 spirit angel took top enormous high mountain',
#  'candylit imagine sarumi zombie apocalypse fighting back back heart heart conversation',
#  'rt zonewolf123 liked youtube video minecraft night lucky block mod bob apocalypse wither 2 0 amp mo',
#  'thats planet lone audience apocalypse',
#  'dad bought dvd look like science doc front read back actually impending biblical apocalypse',
#  'indeed apocalypse come week know ill',
#  'go look grizzly peak right look like beginning dystopian apocalypse movie',
#  'niece asked would scared apocalypse',
#  'there storm cairo latest x men apocalypse set photo via',
#  'minecraft night lucky block mod bob apocalypse wither 2 0 amp mod showcase popularmmos via',
#  'shot heart xv going totally give love bad name heart pierc',
#  'rt geek apocalypse 4pm gmt hesse play dark soul 2 day 9',
#  'know go zombie take',
#  'latest reveals queen',
#  'shadow boxing apocalypse',
#  'short reading apocalypse 21 1023 spirit angel took top enormous high mountain',
#  'enjoyed live action attack titan every time see poster im reminded freshly clean coiffed everyone apocalypse',
#  'liked video minecraft night lucky block mod bob apocalypse wither 2 0 amp mod showcase',
#  'temporary 300 avysss kill flag fast xp reason',
#  'temporary 300 russaky89 kill flag fast xp reason',
#  'official vid gt gt gt gt prod gt gt',
#  'ouvindo peace love amp armageddon',
#  'best movie youve ever seen armageddon',
#  'bed time dont wake unless revolution armageddon start',
#  'red faction armageddon microsoft xbox 360 2011 full read ebay',
#  'already know shit go world series armageddon',
#  'rt lith 9 11',
#  'im gonna beat armageddon hsu hao got flawless first try',
#  'ben affleck know there wife kid girl cant help ive loved since armageddon',
#  'id long coat hand id worn certainty armageddon bear sense occasion',
#  'phone spying hidden back door nsa data mining software financial armageddon blog',
#  'temporary 300 hyider ghost2 kill flag fast xp reason',
#  'rt lith 9 11',
#  'temporary 300 fighterdena kill flag fast xp reason',
#  'photo sketch based taste armageddon episode',
#  'armageddon',
#  'good luck tomorrow night get coefficient point plz',
#  'armageddon',
#  'youre another one history book thank justice department way havent paid income tax 20yrs',
#  'vladimir putin issue major warning late escape armageddon',
#  'god kingdom heavenly govt rule people earth armageddon',
#  'l b lot 8 movie die hard 1 2 12 monkey armageddon sixth',
#  'let talk goof guild saunders come right stage',
#  'niece gaining ability stand im getting prepared toddler apocalypse armageddon',
#  'check must library collection cd via',
#  'eep thought yesterday saw hella scary hail',
#  'ahamedis think messiah already come 125 year ago armageddon dajaal gog amp magog',
#  'sadly window 10 reveals microsofts ethic armageddon',
#  'armageddon averted el patron',
#  'time 23 hour latest series ww1 blueprint armageddon extremely impressive',
#  'european fitba till christmas armageddon',
#  'united jew convert soon die armageddon',
#  'official vid gt gt gt gt gt prod gt gt',
#  'tomorrow day start armageddon',
#  'lee comedy working class tory prepare armageddon',
#  '9 chart prove financial crisis part 2 begun financial armageddon economic collapse blog track tren',
#  'paul craig robert vladimir putin issue major warning late escape',
#  'youre stage right light isnt funny get goofball staff pd',
#  'official vid gt gt gt gt gt gt gt gt gt comin soon',
#  'well done celtic finger crossed aberdeen tomorrow night armageddon eh',
#  'beyonce pick fan army 77',
#  'one direction pick fan army x1402',
#  '5 second summer pick fan army',
#  '22 beyonce pick fan army',
#  '17 beyonce pick fan army',
#  'one direction pick fan army x1411',
#  'seeing army whitewalkers first thing slightly intrigued got far',
#  'build kingdom lead army victory start g friend code lzktjnox',
#  'salvation army host rally reconnect father child salvation army hosting back school rally',
#  'vote v 5th round',
#  'build army 100 dog leader lion dog fight like lion',
#  'show hero tv review',
#  'one direction pick fan army x1392',
#  'infantry men lume dial army analog quartz wrist watch sport blue nylon fabric full rea',
#  'one direction pick fan army x1441',
#  'victorinox swiss army date woman rubber mop watch 241487',
#  'rt drayesha4 indian army ki',
#  '5 second summer pick fan army 1',
#  'beyonce pick fan army 78',
#  'one direction pick fan army x1386',
#  'da one britney spear lana del rey',
#  'one direction pick fan army',
#  'stony jackson america last hope lead army felon thus army reject army satan',
#  'wwi wwii japanese army navy military japan leather watch war mido ww1 2 full read ebay',
#  'beyonce pick fan army 72',
#  '7 beyonce pick fan army',
#  'beyonce pick fan army 66',
#  '6 beyonce pick fan army',
#  'potus appoints brig gen richard g kaiser member mississippi river commission learn mrc',
#  'violent country get army involved help control killing bring back peace poor people',
#  'wwi wwii japanese army navy military japan leather watch war mido ww1 2 full read ebay',
#  'wwi wwii japanese army navy military japan leather watch war mido ww1 2 full read ebay',
#  'one direction pick fan army x1434',
#  'one direction pick fan army',
#  'two jewish terrorist charged historic church arson ugly truth',
#  'spokane authority say theyre struggling solve arson case like today hamilton',
#  'thousand attend rally organized peace protesting arson attack took life',
#  'add familia arson squad',
#  'another fake hate crime lesbian burn house else new',
#  'los angeles time arson suspect linked 30 fire caught northern',
#  'mourning notice stabbing arson victim stir politics grief israel',
#  'mourning notice stabbing arson victim stir politics grief israel',
#  'sound arson',
#  'owner chicago area gay bar admits arson scheme',
#  'wait',
#  'arson suspect linked 30 fire caught northern california',
#  'trial date set man charged arson burglary',
#  'death palestinian toddler arson attack israel crack jewish',
#  'palestinian teen killed amid protest arson attack',
#  'police kisii hunt student failed arson plot police kisii hunt student',
#  'mariah getting thick shoulder poor girl',
#  'mourning notice stabbing arson victim stir politics grief israel poster shira banki',
#  'relaxinpr miprv rt latimes arson suspect linked 30 fire caught northern california',
#  'jewish leader prayed hospital palestinian family treated arson via',
#  'owner chicago area gay bar admits arson scheme via',
#  'angel arson',
#  'police kisii hunt student failed arson plot police kisii hunt student',
#  'mourning notice stabbing arson victim stir politics grief israel',
#  'owner chicago area gay bar admits arson scheme via',
#  'owner chicago area gay bar admits arson scheme',
#  'mourning notice stabbing arson victim stir politics grief israel',
#  'owner chicago area gay bar admits arson scheme',
#  'arson suspect linked 30 fire caught northern california via',
#  'tennessee lesbian couple faked hate crime destroyed home arson',
#  'arson suspect linked 30 fire caught northern california los angeles time',
#  'arson suspect linked 30 fire caught northern california',
#  'hate white people mo',
#  'arsonist mc impressed',
#  'alleged east bay serial arsonist arrested',
#  'minor citation possesion decriminalized substance im facing time',
#  'suspected serial arsonist arrested calif',
#  'arson suspect linked 30 fire caught northern california',
#  'legal system never forgets',
#  'u dick',
#  'bloor ossington arsonist also burned mattress northumberland st',
#  'wheres arsonist',
#  'dont anything nice say come sit',
#  'video show arsonist torching popular bk restaurant strictly vegetarian',
#  'arrested setting many fire watch tonight',
#  'video capture man removing american flag long beach ca home burning arsonist sought',
#  'trick think nasty thing',
#  'take paradise arsonist mc',
#  'make',
#  'town salem melted ice cube bc im arsonist',
#  'arsonist blamed blaze plastic recycling business adelaide report',
#  'hotboy shit',
#  'zodiac girl feat trey dupree produced sparkz beatz chuck da arsonist',
#  'lmfao',
#  'alleged east bay serial arsonist arrested',
#  'im jokin still cant move',
#  'guess u say shit thinking',
#  'arsonist set nyc vegetarian restaurant fire police',
#  'liked video town salem win arsonist',
#  'whats cracking cuz',
#  'smoke good fuck eat drink drive nice car wear green mink',
#  'kill got court day earl',
#  'lmao real live go',
#  'owner chicago area gay bar admits arson scheme frank elliott pleaded guilty hiring arsonist',
#  'trusting iran stop terrorism like inviting arsonist join fire brigade telegraph',
#  'big top burning true story arsonist missing girl',
#  'stay vigilent civil liberty constant attack',
#  'credit inspiring rediscover fantabulous',
#  'nashville theater attack gun grabber demand hatchet control',
#  'breaking terror attack police post',
#  'demi stans really think heart attack sold 5 6 million copy',
#  'scare there new version nuclear attack warning like knowing government still prepare',
#  'isil claim suicide bombing saudi mosque killed least 15',
#  'funniest part twitter feminist try attack 4head',
#  'horrific attack wife muslim italy liveleak',
#  '93 blast accused yeda yakub dy karachi heart attack',
#  'u drone attack kill 4 suspected militant north waziristan',
#  'suspect latest theater attack psychological issue',
#  'militant attack police post udhampur 2 spos injured livemint',
#  'breaking obama official gave muslim terrorist weapon used texas attack',
#  'delhi government provide free treatment acid attack victim private hospital',
#  'new post new smb relay attack steal user credential internet',
#  'israeli force raid home alleged car attack suspect',
#  'heart attack thought goat dead dont worry rocket okay',
#  'im gonna lie im kinda ready attack senior year',
#  'left hand side diamond graveyard shift attack defend right handside fucking idiot',
#  'attack ii volleyball training machine set simulation',
#  'notleys tactful yet direct response harper attack alberta govt hell yeah premier',
#  'police assailant latest u movie theatre attack homeless psychological issue',
#  'thanks damn heart attack',
#  'suspect latest u theatre attack psychological issue',
#  'india shud give evidence 2 pak share terrorist amp use next attack share oth contries',
#  'illegal alien released obama dhs 4 time charged rape amp murder santa maria ca woman prior offense',
#  'strongly condemn attack ary news team karachi cowardly act simply trying job',
#  'nashville theater attack gun grabber demand hatchet control',
#  'fact atomic bomb called little boy fat man say lot mentality went attack',
#  'everyone see ignoranceshe latinoand ever benothing morebut attack dog 4 hate group gop',
#  'heart disease prevention secondhand smoke',
#  'dayton area org tell hit cyber attack',
#  'attack titan game p vita yay cant wait 2016',
#  'nashville theater attack gun grabber demand hatchet control',
#  'anxiety attack',
#  'dog attacked food',
#  'cop injured gunfight militant attack udhampur police post suspected militant attacked police post',
#  'asked feel attacked julie asked frail',
#  'feel attacked',
#  'im feeling attacked',
#  'black men didnt make way white men black men getting attacked',
#  'cant believe fucking ci female going somehow claim offended transgendered female who attacked medium',
#  'israeli helicopter attacked civilian gaza completed exercise greece',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'unit attacked responsible targeting muslim scholar imprisoning youth',
#  'telnet attacked 124 13 172 40 streamyx home southern',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'remember time patrick kane attacked cab driver 20',
#  'im feeling attacked',
#  'ik troll pol rival never literally abused attacked family literally abuse ik loosers',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'worst person questioning julie attacked guy empathy',
#  'kelly osbourne attacked racist donald trump remark latino view',
#  'aiii need chill answer calmly like shes attacked',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'attacked robot lvl 19 ive earned total 6615434 free satoshis',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'saw tweet feel really attacked',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'tv program saw said u air plane flew uranium mine fukushima attacked machine gun student army digging',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'lt thing get attacked',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'avalanche defense match v st louis blue',
#  'liked video kalle mattson avalanche official video',
#  'well crash like avalanche',
#  'men official colorado avalanche reebok shirt xl blue 100 cotton',
#  '2 tix 10 3 frozen fury xvii los angeles king v avalanche 103 row aa mgm grand',
#  'bet didnt know kick box',
#  'little piece wrote avalanche design blog id appreciate greatly checked',
#  'patrick roy 1998 99 upper deck spx finite 1620 made colorado avalanche mint',
#  'musician kalle mattson recreates 34 classic album cover clever music video avalanche',
#  'beautiful sweet avalanche faith akito rose lot frothy gyp',
#  '1 6 tix calgary flame v col avalanche preseason 9 29 scotiabank saddledome',
#  'secret avalanche catechize inner self confidential communication respect creating worth len',
#  'fall leaf poplar fully ordained tumbling avalanche spurgeon',
#  'saw two great punk band making original music last week check em',
#  'great performance chip fuel gas saver chevy tahoe blazer avalanche 10',
#  'musician kalle mattson recreates 34 classic album cover clever music video avalanche',
#  'driving avalanche car week like driving tank',
#  'free ebay sniping rt chevrolet avalanche ltz lifted 4x4 truck please favorite amp share',
#  'chiasson sen cant come deal',
#  'paul rudd emile hirsch david gordon green prince avalanche q amp filmmaker google',
#  'great one time deal avalanche music purchase get neal rigga shirt',
#  'drafted 2005 rd 4 overall played last season',
#  'got video rapper got song',
#  'yo flex im',
#  'avalanche one world away make believing im wide awake',
#  'possible new jersey avalanche next year',
#  'feat watch incredible music video',
#  'avalanche city sunset',
#  'chevrolet avalanche lt 2011 lt used 5 3 l v 8 16 v automatic 4 wd pickup truck premium b',
#  'snowflake avalanche ever feel responsible',
#  'star war power jedi collection 1 battle droid hasbro full read ebay',
#  'civil war general battle bull run hero colonel 2nd new hampshire letter signed',
#  'dragon ball z battle god 2014 rotten tomato via',
#  'added video playlist world tank battle assistant mod bat chat arti kaboom',
#  'ya boy clip v 4kus full battle',
#  'indeed fully aware battle support fight',
#  'baaaack petersens bowhunting battle bow make sure head cast vote',
#  'want battle here war',
#  'kelby tomlinson mild mannered 2nd baseman great metropolitan team fight never ending battle hit rbi way',
#  'black eye 9 space battle occurred star m27329 involving 1 fleet totaling 1236 ship 7 destroyed',
#  'really happened taken king story trailer space battle ripped hole saturn',
#  'battle animation fucking much',
#  'see happens battle block finally',
#  'gon get rap battle',
#  'thing battle internal v external motivation',
#  'check item got',
#  'young german stormtrooper engaged battle somme 1916',
#  'liked video marvel v dc avenger battle',
#  'sigh daily battle',
#  'ive come realization dont attention span mass battle game painting playing',
#  'interested see win battle',
#  'battle goat',
#  'star war power jedi collection 1 battle droid hasbro full read ebay',
#  'black eye 9 space battle occurred star o784 involving 2 fleet totaling 4103 ship 50 destroyed',
#  'remembered around australia descendant grow via',
#  'miss gary buseys son play dixie electronic green fiddle post battle celebration sequence',
#  'news fedex longer transport bioterror germ wake anthrax lab mishap',
#  'fedex longer transport bioterror germ via',
#  'usa today longer transport bioterror pathogen',
#  'fedex longer transport bioterror germ wake anthrax lab mishap via',
#  'jacksonville busines fedex stop shipping potential bioterror pathogen',
#  'fedex longer transport bioterror pathogen wake anthrax lab mishap',
#  'responds fedex longer transport bioterror germ wake anthrax lab mishap',
#  'fedex longer transport bioterror germ wake anthrax lab mishap say fedex',
#  'fedex stop transporting bioterror germ lab mishap fedex stopped transporting certain research',
#  'fedex longer ship potential bioterror pathogen via',
#  'lab faced secret sanction doesnt make cut',
#  'fedex longer transport bioterror germ wake anthrax lab mishap via',
#  'house energy amp amp commerce subcommittee hold 7 28 hearing cdc oversight bioterror lab army anthrax mishap htt',
#  'fedex willing transport research specimen potential bioterror pathogen wake anthrax lab mishap',
#  'fedex longer transport bioterror germ wake anthrax lab mishap',
#  'fedex longer transport bioterror germ wake anthrax lab mishap',
#  'rt alisonannyoung exclusive fedex longer transport research specimen bioterror pathogen wake anthrax lab mishap',
#  'hmm could problem researcher fedex longer transport select agent via',
#  'fedex longer transport bioterror germ wake anthrax lab mishap',
#  'fedex longer transport bioterror germ wake anthrax lab mishap',
#  'fedex longer ship potential bioterror pathogen fedex corp nyse fdx longer deliver package',
#  'fedex longer ship potential bioterror pathogen atlanta business chronicle',
#  'thank longer shipping live microbe department defense',
#  'bioterror manufactured fear state repression',
#  'fedex longer transport bioterror germ via',
#  'fedex stop shipping potential bioterror pathogen',
#  'usatoday today lab faced secret sanction doesnt make cut foxnew',
#  'fedex longer willing transport research specimen potential bioter',
#  'fedex longer transport bioterror germ wake anthrax lab mishap via',
#  'fedex stop shipping potential bioterror pathogen',
#  'fedex longer transport bioterror germ wake anthrax lab mishap',
#  'longer transport bioterror germ wake anthrax lab mishap',
#  'fedex longer shipping bioterror germ wxia tv',
#  'fedex longer transport bioterror germ wake anthrax lab mishap',
#  'usatoday today lab faced secret sanction doesnt make cut foxnew',
#  'fedex longer transport bioterror germ wake anthrax lab mishap via',
#  'biolab safety concern grow fedex stop transporting certain specimen research facility dumbfounded action',
#  'fight bioterrorism sir',
#  'liked video fema region iii targeted bioterrorism nasa japan rocket launch lithium',
#  'cdc carry extensive review lab safety pathogen handling procedure',
#  'firepower lab automation fight infectious disease bioterrorism',
#  '90blks amp 8whts colluded 2 take wht f auth hostage amp 2 make look blk w bioterrorism amp use lgl org idis id still',
#  'great iran deal cover bioterrorism got cut terrible keep good work',
#  'tale two pox body horror',
#  'bioterrorism public health superbug biolabs epidemic biosurveillance outbreak homeland security news wire',
#  'creation ai climate change bioterrorism mass automation workforce contact life wealth inequality yea weve got easy',
#  'lie trust cia hollywood bioterrorism len horowitz vaccine nwo',
#  'satan daughter shadow warrior 50ft woman aka transgender mode p nyc fold extra extra center bioterrorism',
#  'yes would think since college 88 92 difficult think bioterrorism esp bc dispersed',
#  'volunteer needed participate emergency preparedness drill simulating bioterrorism disaster',
#  'major american newspaper running series alleged bioterrorism research going 2 n',
#  'fight bioterrorism sir',
#  'cdc pretty cool list bioterrorism agent 3',
#  'government expert concerned possible bioterrorism using gm organism scientist concerned',
#  'prepare u hhs selects 9 regional special treatment center',
#  'support sys 4 auth taken hostage blk u clergyforced 2 exist younger amp grossly disfigured bioterrorism',
#  '70 70 amp think possibility full transformation impossible dont quite like medical mystery bioterrorism suck',
#  'fight bioterrorism sir',
#  'book describing future therapy technology sport sexuality bioterrorism diagnosis',
#  'w ugliness due 2 ugly frat bioterrorismim who id u tolewantg another home',
#  '90blks amp 8whts colluded 2 take wht f auth hostage amp 2 make look blk w bioterrorism amp use lgl org idis id still',
#  'fight bioterrorism sir',
#  '90blks amp 8whts colluded 2 take wht f auth hostage amp 2 make look blk w bioterrorism amp use lgl org idis id still',
#  '74 75 bioterrorism 2 evade lgl effort 2 prosecute blks 4 kidnapg',
#  'cover nuclear activity bioterrorism iran broken least 27 agreement',
#  'threat anthrax cdc via',
#  'authority allay fear ahead rio olympic equestrian test event via',
#  'craving u',
#  'ive pool day',
#  'know anyone looking move hammond share listing',
#  'life amazin time crazy nigga dey wanna blaze hate made took dedication n motivation',
#  'blaze bro',
#  'yes love',
#  'see virtual tour one listing 547 fir st cannon beach listed dorrie caruana',
#  'pendleton medium office said fire base right horno blaze',
#  'welcome',
#  'love living blaze inside apt balcony',
#  'alrighty hit well blaze',
#  'blaze jay fuck dutch slave trade',
#  'hair poverty moment need get fade weekend get',
#  'property loss california wildfire nearly double week old blaze rage',
#  'firefighter battling blaze east cary condo building',
#  'nigga love hating',
#  'dont like babe lt 3 youll ball fun lan',
#  'liked video minecraft skywars blaze que usa hack e flechadas sinistras',
#  'dems blaze covered month ago chicago police detained thousand black american interrogation facility',
#  'yo got bar im even rapper',
#  'ugh blaze put calorie pizza ok cool',
#  'pic blaze fort kid look like jackass stuffin face like',
#  'look like year writing computer ahead',
#  'letting know',
#  'im mad 420 name amp dont blaze',
#  'yeah know blaze blue dont twitter lol drew week ago',
#  'news new facebook page feature seek help personalize customer experience',
#  'shout blaze hottest dj sothwest',
#  'liked video minecraft episode 2 blaze farm beginning',
#  'property loss wildfire nearly double week old blaze rage fire',
#  'work yet see new vela short blaze',
#  'total tweet fail beautiful inside blaze',
#  'mixtape coming promise goin right',
#  'huh leo started last year ever since people blaze back',
#  '3 bedroom 1 bath sale 29 palm ca youtube video',
#  'yes 2 gun',
#  'daem girl smooth asf c',
#  'say agree',
#  'bright amp blazing fireman birthday party',
#  'real vibez radio blazing best vibez',
#  'montgomery come blazing hot weather stay std yet another rejected city slogan',
#  'come join u tomorrow august 7 2015 transcend blazing trail diversified world marketing',
#  'morgan silver dollar 1880 gem bu dmpl cameo rev blazing m high grade full read',
#  'morgan silver dollar 1880 gem bu dmpl cameo rev blazing m high grade full read',
#  'bowl got thinking damn ive blazing damn long',
#  'he blazing game best stealth skill yet nothing beat silenced m4',
#  'bit pacquiao v marquez 3 unfilled blazing swarm online durvod',
#  'turn radio live amp 107 9 fm blazing hit',
#  '32 inch dynasty',
#  'im weapon master let go gun blazing',
#  'really sadly come expect obama',
#  'shouout cause vocal blazing hot like weather shes',
#  's3xleak ph0tos 19yrs old ash lady festac town delta exp0sed bbm 5 leaked picture',
#  'oh heart racing temperature blazing roof fifth harmony',
#  'haha love',
#  'colorado spanish word meaning reddish colored dummy pronouncing wrong',
#  'traffic freezing cold blazing hot heat traffic',
#  'im crazy enough run 95 degree mid day heat blazing sun place im',
#  'im blazing rn there nothing stop',
#  'still blazing',
#  'thanks sweat bullet every time get blazing sun beating',
#  'blazing',
#  'lost word made new fan fam crazy skill beyond blessed keep blazing dude made love respect',
#  'let hot blazing fantasy',
#  'thank missy thought suited blazing hot summertime yee haw',
#  'magical bag blazing',
#  'blazing elwoods dont bother dougs song tune',
#  'morgan silver dollar 1921 p ch gem bu pl blazing m satin rare proof like full',
#  'blazing hot etisalat free mb complete 12 month etisalat giving 100mb tecno q1 ime',
#  'want full bitch slapping gun blazing cake throwing charles showdown worth wait',
#  'follow check hit single unpacked man blazing',
#  'still dont know 8 hour physical activity blazing sun isnt sport',
#  'way archetype bleeding well grounded readiness fpoj',
#  'threw chicken nugget sister lip bleeding',
#  'could slit throat id apologize bleeding',
#  'joe landolina gel make stop bleeding instantly',
#  'nose bleeding last one like 10 year ago',
#  'bleeding typewriter day far ive written bunch gunk',
#  'cant help hope youre ok text need talk sending hug way p bleeding death allowed',
#  'stab back promise youll one bleeding',
#  'apparently youre bleeding people look weird lol well fine keep walking',
#  'eating takis rubbing eye hand eye bleeding tear',
#  'yea heard coming 2017 2019 vampiro bleeding',
#  'look broken bleeding',
#  'hit foot toe bleeding',
#  'long see madara bleeding im good',
#  'keep thinking stepped broken glass pun tak sedar dont feel pain also bleeding shit',
#  'ear bleeding',
#  'waited 2 5 hour get cab foot bleeding',
#  'cute dinner date til cam nose start bleeding',
#  'head like yo nose bleeding',
#  'ive bleeding silence feel safer violence',
#  'fell someone back hit head concrete bleeding n shit',
#  'yes im bleeding heart liberal',
#  'deadpool already one favourite marvel character know wear red suit bad guy cant tell he bleeding',
#  'defs stop bleeding',
#  'know u youre bleeding heart wannabe pickup artist',
#  'awesome saw bleeding pretty bad',
#  'bleeding brain dont know cause',
#  'let see good soccer youre bleeding yo face',
#  'bleeding wild thing running around apartment he work bar',
#  'bleeding instinct kicked look away scratch back head',
#  'ear bleeding hate stefano',
#  'ear started bleeding',
#  'saw pileup tv keep racing even bleeding',
#  'rave wedding seeing eye bleeding',
#  'say bad thing happen reason wise word gonna stop te bleeding',
#  'yo timeline blew damn fast',
#  'go look blew w atomic bomb',
#  'blew instagrams cause shes cute shes active follower',
#  'see crazy line blew',
#  'instagram blew apparently featured jazz tonight cool love',
#  'id still team usagi even blew entire solar system airhead misstep',
#  'remember u like 4 0 blew one game u probs dont king cup',
#  'hate people tweet receipt know wrong wont take bc blew literally gtfo youre desperate',
#  'think blew notification go check shes encouraging love',
#  'hw18 going 90 100 dude keeping took exit pulled side told blew motor lolol',
#  'universe might actually exist scientist say blew began',
#  'max blew tf shot fired',
#  'rick morty blew',
#  'ty blew motor went flame got ok',
#  'realized dude way blew tusky game',
#  'night blew rq',
#  'blew snapchat reason',
#  'queen gambit went well anakin blew droid control ship oh well still fun cant stop next',
#  'ironically michele bachmann brought 11 w ron paul amp everyone blew called hoax finally right',
#  'catfish retweeted amp notification blew',
#  'guy whistled parking lot amp help wind blew skirt getting car',
#  'blew mention',
#  '1st time someone blew phone 30 time would blocked believe',
#  'like literally blew',
#  'freya video blew everywhere',
#  'easy way look good ray rice fiasco blew',
#  'lmao light skin guy blew twitter talking ugly kid',
#  'watched honey blew economy recommend conservative shoppe horror',
#  'anyone else see fireball falling earth look like plane blew',
#  'ye thing big sean still blew',
#  'zayn blew twitter',
#  'bitch done blew shit',
#  'damn clue tried see many click could get blew thats played',
#  'great pair like couple graywardens fighting blight',
#  'there actually theory magisters arent reason blight dwarf one',
#  'cycling fan feel sorry world athletics blight exacerbated monetary reward lot soul searching required',
#  'blight',
#  'poor jack',
#  'agree knew wed going deep road found blight red lyrium aint yet gt gt',
#  'get load welfare loving sponge blight society',
#  'new post prysmian secures contract blight bank wind farm',
#  'cleveland height shaker height fight blight house next door',
#  'wanted see info blight u got',
#  'carl everest rob cobes whitt blight frost leo snuff godly others drink beer someday',
#  'thda kick anti blight loan effort memphis',
#  'city program help turn blight greenspace tennessee housing development',
#  'yes want new blight leader',
#  'release planing level 1 constellation blight gaia iclowns drumstep remix 2 iclown infinity',
#  'cleveland height shaker height fight blight house next door',
#  'going achieve excellence big thing develop habit little matter dont know author',
#  'sure purdies alive blight',
#  'tracy blight thank following',
#  'apperception bridgework blight xxhjesc',
#  'dotish blight car go right ahead mine',
#  'sexual revolution blight woman story via',
#  'like swear secret well uncover old god slumber think there gonna another blight',
#  'double result live app',
#  'first one want use community never asked blight park',
#  'look policy matter ohio report cuyahoga county blight greening vacant land soon',
#  'put taint magisters open gate let blight get away',
#  'theory make way much sense say dwarf may actual origin blight',
#  'tragedy blight humanity amp shame every living',
#  'article michael jackman metro time detroit group later downgraded estimate 37 square mile',
#  'locksmithing art respecting elaboration blight lock lpdkl',
#  'cunt',
#  'every 5000 win ranked play gave special card back would cool long te',
#  'amazon deal wait buy',
#  'new print available waiting long pamela blizzard',
#  'give free art kamon',
#  'order blizzard pay put nut say ball flavored boom free ice cream',
#  'blizzard auz 9 pm cst 2 hr rock make hump day complete',
#  'really want rolo blizzard mom said guess dq tonight',
#  'hi ashayo believe vods youtube presentation nothing like seeing live',
#  'stats',
#  'dolphin worship group based superstition take look tweet',
#  'lucio let get hype train rolling caution though arent break',
#  'ight',
#  'peanut butter cookie dough blizzard',
#  'mic controller arent working one second',
#  'tomorrow announcement vods',
#  'updated window 10 get error',
#  'new expansion idea bard class holy trinity 1',
#  'really shocking blizzard lured old fanbase back wod disappointed u hardcore everyones leaving',
#  'best thing dq cotton candy blizzard',
#  'lizard wizard blizzard',
#  'need',
#  'please blizzard love',
#  'blizzard would clutch asf',
#  'also please would much like link',
#  'ok ok okayyyyyy ima act right bout get blizzard tho',
#  'control tora',
#  'first time playing hearthstone pc thought',
#  'love cotton candy blizzard',
#  'hard reset xbox',
#  'really wanna brownie batter blizzard',
#  'call little bit blizzard',
#  'market news activision blizzard cognizant technology first solar',
#  'sean end career sg blizzard v knockout',
#  'biggest regret hearthstone',
#  'someone walk dq wanna butterfinger blizzard bad',
#  'horrible moment u open dryer look like snowy blizzard cuz u left piece paper jean pocket',
#  'bruh dy',
#  'rip blood',
#  'nah young blood cook gone im cut haha',
#  'wall invincible history blood dance floor',
#  'broke nail real fake morning blood ah hurt idea treat help pretty please',
#  '4 5 5 star 290 reviewer dragon blood boxset lindsay buroker',
#  'blood group associated gastric carcinoma say text book another fragile gene body',
#  'friend like blood beside u always come wounded',
#  'gone get get blood',
#  'people u allowed donate blood receive blood well',
#  'dialysis grandpa oh lord blood make light headed',
#  'dad dont claim mean right look eye blood xbox 360 smh',
#  'omron hem 712c automatic blood pressure monitor standard large bp cuff',
#  'blood pressure roof dont need extra shit',
#  'yeah',
#  'cant believe people mid 20 dont high blood pressure life stressful',
#  'guy imouto isnt actually related blood',
#  'bruh white people buy ugliest shoe super tight blood going foot',
#  'another day another excellent porridge seriously people blood orange porridge phenomenal',
#  'happy birthday young blood',
#  'wasnt blood',
#  'kinda shii nasty blood pun intended',
#  'aint hoe blood',
#  'today hastle getting drug tested blood drown tb shot document filling',
#  'man somebody gotta stop sbee dude fuckin funny blood',
#  'wind take gypsy blood time',
#  'mad men',
#  'private thirsty night sad blood rockn roll',
#  'ellie goulding blood acesse nosso site para ouvir',
#  'welcome read free chapter new book encounter jesus full hope',
#  'run blood',
#  'personal favorite include paramore muse green day royal blood 5sos',
#  'shed innocent blood son daughter land polluted psalm 106 38 help stop sin abortion',
#  'se pone cantar cry lightning',
#  'wasnt big stab deep stab there like blood everwhe',
#  'add item everyday eating habit please research take blood',
#  'looooooooooool bloody hell',
#  'infected bloody ear piercings always fun',
#  'aggressif bloody aggressive',
#  'entered entire set butterlondon lip crayon via go enter',
#  'hey sally sorry emailed awol bloody work argh',
#  'im listening bloody jay',
#  'forrest version 83 thats bloody awful well xxx',
#  'nightmare elm street getting remade',
#  'cant bloody wait sony set date stephen king dark tower',
#  'gotta try let go many bloody thing smh',
#  '1 russia may played reason link b okanowa bloody mainline invasion looked like bloody',
#  'bloody insomnia grrrr',
#  'tried 11 eye akame ga kill tokyo ghoul damn bloody dont dare watch',
#  'suck thats youre bloody getting mean amends',
#  'call weekend call bloody mary time summer full new',
#  'bloody hell day havent even really done anything tired everything thought vaca would help much',
#  'damn bloody hot',
#  'bloody sexy drool',
#  'know say side effect low amp really fast son product acne cream 1 side effect bloody diarrhea',
#  'ronda rousey would close making floyd mayweathers money 50 fight bloody elbow',
#  'im awful painting agree a3 landscape bloody oil paint',
#  'need life sin girlfriend ride till bloody end girlfriend',
#  'think well bloody barking',
#  'eh hello cover bloody thigh bloody cleav eh hello since expose cleavage',
#  'mega bloody marvellous',
#  'bloody mary sink beet juice',
#  'monty python date bloody far want go',
#  'meet bloody rs5',
#  'friday supposed happy day bloody friday hah zzzz',
#  'bloody hope said folding arm sitting back chair',
#  'wait tell college friend reafs bloody mary drama cd',
#  'came kill indian fun video smirking remorseless pakistani killer show boasting',
#  'ive watched episode s01e09 bloody monday',
#  'marlon williams gt elvis presley gt marlon williams gt steel panther shuffle mode like bloody legend',
#  'black friday turn bloody would rather shopping',
#  'someone told soccer mom getting pic blown put daughter bedroom wall',
#  's2g mention get blown choice deactivate leave good respect choice',
#  'wow wow club blown money fucked player like theyd pilloried',
#  'damn greinke got blown first inning',
#  'woke blown lol',
#  'aunt marge youre blown eheks',
#  'yeah worth bc already many spammer amp twitter probably blown every second',
#  'white family supposedly representing america great value get blown horrible cgi nuclear strike lmfaoooo',
#  'man hasnt blown he still underground',
#  'mention blown wtf',
#  '1862 confederate ship blown crew read via',
#  'moment ur win mini uhc get blown creeper get kicked flying salty rn',
#  'get bump approval probably he blown',
#  'truckload soldier blown nobody panic one little lion dy everyone loses mind',
#  'hey look kashs foundation live today got blown people magazine website todd blake',
#  'got last month went ee shop glad hasnt blown yet',
#  'first time tweet blown almost half day later',
#  'blown away extension nothing seen many option one',
#  'thanks letting stay since manor blown anyways buddy',
#  'loner diary pattern sand may blown away photo two choked flame',
#  'even though bsg sufficiently hyped year somehow delayed watching utterly utterly blown away',
#  'vanessa game officially blown lady gentleman real show begin',
#  'guaranteed bitten mutant mosquito ankle blown little cunt',
#  'thing pick tozlet seat butt leprosy full blown jerkface syndrome lateral lisp amp toilet rickets',
#  'ig blown hacker need stop',
#  'whoever directing video need grab nicki minaj someone u recognition mind blown',
#  'last week wanted 6th sense get blown far good james could win he huge target gone soon',
#  'like blown amirite',
#  'dog blown kennel bloody yorkshire terrorist',
#  'turn espn2 get blown',
#  'went beaten blown next thing know ra al ghul brought back life escaped',
#  'leo as got metaphorically blown',
#  'glononium 6c also help blown bashing bottle nitroglycerin book',
#  'new lady shoulder tote handbag woman cross body bag faux leather fashion purse full',
#  'new lady shoulder tote handbag woman cross body bag faux leather fashion purse full',
#  'son daughter would like see going war iran come back body bag let know',
#  'ditto way feel drank vodka ice would body bag',
#  'handbag genuine mulberry antony cross body messenger bag dark oak soft buffalo leather 279 00end date w',
#  'louis vuitton monogram sophie limited edition clutch cross body bag full read ebay',
#  'louis vuitton monogram sophie limited edition clutch cross body bag full read ebay',
#  'louis vuitton cultsierre monogram shoulder bag cross body bag',
#  'check ameribag healthy back bag shoulder cross body backpack khaki tan beige nylon',
#  'photo bath amp body work cosmetic bag periwinkle blue copper piping along top four corner',
#  'new lady shoulder tote handbag woman cross body bag faux leather fashion purse full',
#  'new summer long thin body bag hip word skirt blue',
#  'new lady shoulder tote faux leather hobo purse cross body bag rt en',
#  'bruh wanna fight im meet cage bro better find youre dealing end body bag',
#  'new lady shoulder tote handbag faux leather hobo purse cross body bag woman full read',
#  'auth louis vuitton brown saumur 35 cross body shoulder bag monogram 7 23 419 3 full read',
#  'check vintage longaberger floral fabric shoulder cross body bag brown leather strap',
#  'new lady shoulder tote faux leather hobo purse cross body bag',
#  'new summer long thin body bag hip word skirt blue',
#  'new lady shoulder tote faux leather hobo purse cross body bag rt en',
#  'louis vuitton monogram sophie limited edition clutch cross body bag full read ebay',
#  'new woman handbag faux leather lady shoulder tote cross body bag large satchel full',
#  'new lady shoulder tote faux leather hobo purse cross body bag',
#  'one day heart gone get zipped body bag',
#  'authentic louis vuitton pochette bosphore shoulder cross body bag',
#  'new lady shoulder tote faux leather hobo purse cross body bag',
#  'vintage coach purse camera bag cross body 16 99 0 bid',
#  'genuine leather man bag messenger fit ipad mini 4 tablet case cross body air jp full rea',
#  'louis vuitton monogram sophie limited edition clutch cross body bag full read ebay',
#  'new lady shoulder tote faux leather hobo purse cross body bag',
#  'nuu fam fwt im leave body bag',
#  'new lady shoulder tote handbag faux leather hobo purse cross body bag woman full read',
#  'im im saying theyre lucky go home family put body bag',
#  'oh im bagging body bangin im saying shes going get rose',
#  'bagging body shes smoking hot',
#  'drake really body bagging meek',
#  'drake killing dude tea bagging dead body point',
#  'w rec k league ball olympic level body bagging like career nothing',
#  'idgaf tough canada north philly meek acting like bitch amp drake body bagging as track',
#  'body bagging mf',
#  'skimmed twitter missed body bagging',
#  'g body bagging lyrically',
#  'straight body bagging',
#  'body bagging bitch',
#  'better feeling seeing stage day one 22 year friendship still body bagging mics together',
#  'mopheme bigstar johnson problem game body bagging nigga',
#  'body bagging today 4got post score',
#  'let bagging body begin lol aint cuffed yet shouldnt bad',
#  ...]

# %%
cv = CountVectorizer()
X2 = cv.fit_transform(trainclean1).toarray()
y2 = dftrain1["target"]
X_train, X_test, y_train, y_test = train_test_split(X2, y2, test_size=0.3)

# %%
model=MultinomialNB()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
model.fit(X_train, y_train)
cf=classification_report(y_test,y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81      1292
#            1       0.77      0.70      0.73       992
#
#     accuracy                           0.78      2284
#    macro avg       0.78      0.77      0.77      2284
# weighted avg       0.78      0.78      0.78      2284

# %%
model1 = DecisionTreeClassifier()
model1.fit(X_train, y_train)
y_pred=model1.predict(X_test)
cf=classification_report(y_test,y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.73      0.74      1292
#            1       0.66      0.67      0.67       992
#
#     accuracy                           0.71      2284
#    macro avg       0.70      0.70      0.70      2284
# weighted avg       0.71      0.71      0.71      2284

# %%
model2 = LogisticRegression()
model2.fit(X_train, y_train)
y_pred=model2.predict(X_test)
cf=classification_report(y_test,y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.87      0.82      1292
#            1       0.80      0.67      0.72       992
#
#     accuracy                           0.78      2284
#    macro avg       0.78      0.77      0.77      2284
# weighted avg       0.78      0.78      0.78      2284

# %%
model3 = RandomForestClassifier(n_estimators = 100)
model3.fit(X_train, y_train)
y_pred=model3.predict(X_test)
cf=classification_report(y_test,y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.83      0.80      1292
#            1       0.75      0.67      0.71       992
#
#     accuracy                           0.76      2284
#    macro avg       0.76      0.75      0.75      2284
# weighted avg       0.76      0.76      0.76      2284

# %%
model4 = RidgeClassifier()
model4.fit(X_train, y_train)
y_pred = model4.predict(X_test)
cf = classification_report(y_test, y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.83      0.79      1292
#            1       0.74      0.64      0.69       992
#
#     accuracy                           0.75      2284
#    macro avg       0.75      0.74      0.74      2284
# weighted avg       0.75      0.75      0.75      2284

# %% [markdown]
# ### Running the models with a lemmatizer and Tfidf Vectorizer

# %%
tf = TfidfVectorizer()
X1_idf = tf.fit_transform(trainclean1).toarray()
y3 = dftrain1["target"]
X_train, X_test, y_train, y_test = train_test_split(X1_idf, y3, test_size=0.3)

# %%
model=MultinomialNB()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
cf=classification_report(y_test,y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.90      0.84      1332
#            1       0.83      0.66      0.73       952
#
#     accuracy                           0.80      2284
#    macro avg       0.81      0.78      0.79      2284
# weighted avg       0.80      0.80      0.80      2284

# %%
model1 = DecisionTreeClassifier()
model1.fit(X_train, y_train)
y_pred=model1.predict(X_test)
cf=classification_report(y_test,y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.72      0.75      1332
#            1       0.65      0.73      0.69       952
#
#     accuracy                           0.72      2284
#    macro avg       0.72      0.72      0.72      2284
# weighted avg       0.73      0.72      0.73      2284

# %%
model2 = LogisticRegression()
model2.fit(X_train, y_train)
y_pred=model2.predict(X_test)
cf=classification_report(y_test,y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.92      0.85      1332
#            1       0.85      0.65      0.74       952
#
#     accuracy                           0.81      2284
#    macro avg       0.82      0.79      0.79      2284
# weighted avg       0.81      0.81      0.80      2284

# %%
model3 = RandomForestClassifier(n_estimators = 100)
model3.fit(X_train, y_train)
y_pred=model3.predict(X_test)
cf=classification_report(y_test,y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.84      0.82      1332
#            1       0.76      0.69      0.72       952
#
#     accuracy                           0.78      2284
#    macro avg       0.78      0.77      0.77      2284
# weighted avg       0.78      0.78      0.78      2284

# %%
model4 = RidgeClassifier()
model4.fit(X_train, y_train)
y_pred = model4.predict(X_test)
cf = classification_report(y_test, y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84      1332
#            1       0.81      0.69      0.75       952
#
#     accuracy                           0.81      2284
#    macro avg       0.81      0.79      0.79      2284
# weighted avg       0.81      0.81      0.80      2284

# %% [markdown]
# ### Best F1-score is Logistic Regression with a Tfidf vectorizer
# ### Let's test the model

# %%
x = dftrain1["text"]
y = dftrain1["target"]
x_final = dftest1["text"]

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
tf = TfidfVectorizer()
X_train = tf.fit_transform(X_train).toarray()
X_test = tf.transform(X_test).toarray()
X_pred = tf.transform(x_final).toarray()

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
finalmodel = lr.predict(X_pred)
finalmodel
# Out:
# array([1, 0, 1, ..., 1, 1, 0], dtype=int64)

# %%
submission = dftest1[['id']].reset_index(drop=True)
submission['target'] = finalmodel.astype('int64')

# %%
submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3263 entries, 0 to 3262
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      3263 non-null   int64
#  1   target  3263 non-null   int64
# dtypes: int64(2)
# memory usage: 51.1 KB

# %%
submission.to_csv("submission.csv", index=False)
